# %%
#standard ds imports
import pandas as pd
import numpy as np
#viz and stats
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# .py imports
#import wranglerer as wr
#import modeling as md
import os
#sklearn imports
from sklearn.model_selection import train_test_split,cross_val_score, GridSearchCV
import sklearn.preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix, plot_confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
#CATboost imports
from catboost import CatBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
import explore_r as ex
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %% [markdown]
# ### This notebook builds upon the previous notebook (model_r) and incorporates GridSearch CrossValidation to explore each algorithm with a small subset of possible hyperparameter combinations.

# %%
df = pd.read_csv('prepped_data.csv')

# %%
df = df.drop(columns=['date', 'day_of_week', 'start_time','home_score',
       'home_wins', 'away_score', 'away_wins','total_scores'])
df['spread'] = abs(df['spread'])

# %%
df.head()
# Out:
#    week_num                          stadium  temp  humidity  wind  spread  \
# 0        19               State Farm Stadium    72         0     0     1.0
# 1        19          Lincoln Financial Field    52        48    14     2.5
# 2        19  GEHA Field at Arrowhead Stadium    22        55    13     1.5
# 3        19                 Highmark Stadium    32        10     0     5.5
# 4        19                   Levi's Stadium    55        47    19     4.0
#
#      ou  is_under  abnormal_start  is_playoff  playoff_implications  is_turf  \
# 0  51.0         0               0           1                     1        0
# 1  45.5         1               0           1                     1        0
# 2  48.0         1               0           1                     1        0
# 3  49.0         1               0           1                     1        1
# 4  47.0         1               0           1                     1        0
#
#    is_outdoor
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10811 entries, 0 to 10810
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   week_num              10811 non-null  int64
#  1   stadium               10811 non-null  object
#  2   temp                  10811 non-null  int64
#  3   humidity              10811 non-null  int64
#  4   wind                  10811 non-null  int64
#  5   spread                10811 non-null  float64
#  6   ou                    10811 non-null  float64
#  7   is_under              10811 non-null  int64
#  8   abnormal_start        10811 non-null  int64
#  9   is_playoff            10811 non-null  int64
#  10  playoff_implications  10811 non-null  int64
#  11  is_turf               10811 non-null  int64
#  12  is_outdoor            10811 non-null  int64
# dtypes: float64(2), int64(10), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# ## ESTABLISH BASELINE 50.7%

# %%
df.is_under.value_counts(normalize=True)
# Out:
# 1    0.507354
# 0    0.492646
# Name: is_under, dtype: float64

# %%
df['baseline'] = 1

# %%
baseline_accuracy = (df.baseline == df.is_under).mean()
print(f'baseline accuracy: {baseline_accuracy:.2%}')
# Out:
# baseline accuracy: 50.74%

# %%
subset = df[df.is_under == 1]
baseline_recall = (subset.baseline == subset.is_under).mean()
print(f'baseline recall: {baseline_recall:.2%}')
# Out:
# baseline recall: 100.00%

# %%
subset = df[df.baseline == 1]
baseline_precision = (subset.baseline == subset.is_under).mean()
print(f'baseline precision: {baseline_precision:.2%}')
# Out:
# baseline precision: 50.74%

# %%
df.drop(columns='baseline',inplace=True)

# %%
df_no_stadium = df.drop(columns='stadium')

# %%
df_no_stadium.head()
# Out:
#    week_num  temp  humidity  wind  spread    ou  is_under  abnormal_start  \
# 0        19    72         0     0     1.0  51.0         0               0
# 1        19    52        48    14     2.5  45.5         1               0
# 2        19    22        55    13     1.5  48.0         1               0
# 3        19    32        10     0     5.5  49.0         1               0
# 4        19    55        47    19     4.0  47.0         1               0
#
#    is_playoff  playoff_implications  is_turf  is_outdoor
# 0           1                     1        0           0
# 1           1                     1        0           1
# 2           1                     1        0           1
# 3           1                     1        1           1
# 4           1                     1        0           1

# %%
X_train, y_train, X_validate, y_validate, X_test, y_test = ex.train_validate_test(df_no_stadium,'is_under')

# %%
X_train.shape, y_train.shape, X_validate.shape, y_validate.shape, X_test.shape, y_test.shape
# Out:
# ((6471, 11), (6471,), (2394, 11), (2394,), (1946, 11), (1946,))

# %%
X_train.head()
# Out:
#       week_num  temp  humidity  wind  spread    ou  abnormal_start  \
# 1713        12    72         0     0     4.0  49.0               0
# 2164        17    72         0     0     7.5  38.0               0
# 2554         9    72         0     0     1.0  42.5               1
# 3117         6    58        52    10    12.5  40.0               0
# 9819        13    51        49    14     5.0  39.5               0
#
#       is_playoff  playoff_implications  is_turf  is_outdoor
# 1713           0                     1        1           0
# 2164           0                     1        0           0
# 2554           0                     0        0           0
# 3117           0                     0        0           1
# 9819           0                     1        0           1

# %% [markdown]
# # MODELING

# %% [markdown]
# ## DTC VANILLA

# %%
# create the Decision Tree Classifier model 
dtc = DecisionTreeClassifier()

# %%
# fit the model to the TRAIN dataset:
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# use the model by calling for the predictions made via the TRAIN dataset
dtc_preds = dtc.predict(X_train)
pd.crosstab(dtc_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         3180    20
# 1            0  3271

# %%
print(f'Accuracy-Train {round(dtc.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(dtc.score(X_validate,y_validate),4)}')
print(classification_report(y_train,dtc_preds))
print(classification_report(y_validate,dtc.predict(X_validate)))
# Out:
# Accuracy-Train 0.9969
# Accuracy-Validate 0.5146
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3180
#            1       1.00      0.99      1.00      3291
#
#     accuracy                           1.00      6471
#    macro avg       1.00      1.00      1.00      6471
# weighted avg       1.00      1.00      1.00      6471
#
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.50      1178
#            1       0.52      0.53      0.53      1216
#
#     accuracy                           0.51      2394
#    macro avg       0.51      0.51      0.51      2394
# weighted avg       0.51      0.51      0.51      2394

# %% [markdown]
# ## DTC maxDepth = X

# %%
# create the Decision Tree Classifier model 
dtc = DecisionTreeClassifier(max_depth=5,min_samples_leaf=5)

# %%
# fit the model to the TRAIN dataset:
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=5)

# %%
# use the model by calling for the predictions made via the TRAIN dataset
dtc_preds = dtc.predict(X_train)
pd.crosstab(dtc_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         1604  1365
# 1         1576  1926

# %%
print(f'Accuracy-Train {round(dtc.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(dtc.score(X_validate,y_validate),4)}')
print(classification_report(y_train,dtc_preds))
print(classification_report(y_validate,dtc.predict(X_validate)))
# Out:
# Accuracy-Train 0.5455
# Accuracy-Validate 0.5029
#               precision    recall  f1-score   support
#
#            0       0.54      0.50      0.52      3180
#            1       0.55      0.59      0.57      3291
#
#     accuracy                           0.55      6471
#    macro avg       0.55      0.54      0.54      6471
# weighted avg       0.55      0.55      0.54      6471
#
#               precision    recall  f1-score   support
#
#            0       0.49      0.46      0.48      1178
#            1       0.51      0.55      0.53      1216
#
#     accuracy                           0.50      2394
#    macro avg       0.50      0.50      0.50      2394
# weighted avg       0.50      0.50      0.50      2394

# %% [markdown]
# ## DTC grid_search CROSS_VALIDATION k=5

# %%
cross_val_score(dtc, X_train, y_train, cv=10)
# Out:
# array([0.50308642, 0.52550232, 0.46367852, 0.47449768, 0.50695518,
#        0.51931994, 0.51931994, 0.51468315, 0.51468315, 0.5007728 ])

# %%
param_grid = {
    'max_depth': [None,18, 12, 10, 5],
    'min_samples_leaf': [1, 5, 10, 20],
    'criterion': ['gini', 'entropy'],
}

# %%
gr_search = GridSearchCV(DecisionTreeClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 18, 12, 10, 5],
#                          'min_samples_leaf': [1, 5, 10, 20]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 18, 12, 10, 5],
#                          'min_samples_leaf': [1, 5, 10, 20]})

# %%
results = gr_search.cv_results_

# %%
results_df_init = pd.DataFrame(results)

# %%
results_df_init.shape
# Out:
# (40, 16)

# %%
params = pd.DataFrame(results['params'])

# %%
params
# Out:
#    criterion  max_depth  min_samples_leaf
# 0       gini        NaN                 1
# 1       gini        NaN                 5
# 2       gini        NaN                10
# 3       gini        NaN                20
# 4       gini       18.0                 1
# 5       gini       18.0                 5
# 6       gini       18.0                10
# 7       gini       18.0                20
# 8       gini       12.0                 1
# 9       gini       12.0                 5
# 10      gini       12.0                10
# 11      gini       12.0                20
# 12      gini       10.0                 1
# 13      gini       10.0                 5
# 14      gini       10.0                10
# 15      gini       10.0                20
# 16      gini        5.0                 1
# 17      gini        5.0                 5
# 18      gini        5.0                10
# 19      gini        5.0                20
# 20   entropy        NaN                 1
# 21   entropy        NaN                 5
# 22   entropy        NaN                10
# 23   entropy        NaN                20
# 24   entropy       18.0                 1
# 25   entropy       18.0                 5
# 26   entropy       18.0                10
# 27   entropy       18.0                20
# 28   entropy       12.0                 1
# 29   entropy       12.0                 5
# 30   entropy       12.0                10
# 31   entropy       12.0                20
# 32   entropy       10.0                 1
# 33   entropy       10.0                 5
# 34   entropy       10.0                10
# 35   entropy       10.0                20
# 36   entropy        5.0                 1
# 37   entropy        5.0                 5
# 38   entropy        5.0                10
# 39   entropy        5.0                20

# %%
results_df_init.sort_values(by='rank_test_score').head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 37       0.004864      0.000021         0.000457        0.000005
# 0        0.021075      0.007536         0.000869        0.000383
# 2        0.010786      0.000418         0.000540        0.000002
# 24       0.014250      0.000195         0.000534        0.000003
# 38       0.004841      0.000067         0.000453        0.000007
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 37         entropy               5                      5
# 0             gini            None                      1
# 2             gini            None                     10
# 24         entropy              18                      1
# 38         entropy               5                     10
#
#                                                params  split0_test_score  \
# 37  {'criterion': 'entropy', 'max_depth': 5, 'min_...           0.491892
# 0   {'criterion': 'gini', 'max_depth': None, 'min_...           0.503475
# 2   {'criterion': 'gini', 'max_depth': None, 'min_...           0.501158
# 24  {'criterion': 'entropy', 'max_depth': 18, 'min...           0.504247
# 38  {'criterion': 'entropy', 'max_depth': 5, 'min_...           0.492664
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 37           0.510046           0.522411           0.521638
# 0            0.493818           0.495363           0.526275
# 2            0.501546           0.498454           0.515456
# 24           0.501546           0.512365           0.507728
# 38           0.504637           0.520866           0.519320
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 37           0.508501         0.510898        0.011096                1
# 0            0.533230         0.510432        0.016262                2
# 2            0.534776         0.510278        0.013610                3
# 24           0.520093         0.509196        0.006541                4
# 38           0.507728         0.509043        0.010342                5

# %% [markdown]
# ## RFC grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'max_depth': [None,18, 12, 10, 5],
    'n_estimators': [55, 101, 201],
    'criterion': ['gini', 'entropy'],
}
gr_search = GridSearchCV(RandomForestClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 18, 12, 10, 5],
#                          'n_estimators': [55, 101, 201]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 18, 12, 10, 5],
#                          'n_estimators': [55, 101, 201]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (30, 16)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head(11)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 12       0.086265      0.003047         0.003998        0.000070
# 14       0.307034      0.001641         0.013054        0.000217
# 10       0.236203      0.001197         0.010536        0.000232
# 29       0.309148      0.000893         0.012816        0.000242
# 7        0.261788      0.001410         0.011839        0.000192
# 24       0.134917      0.002064         0.005784        0.000095
# 26       0.486141      0.001357         0.019801        0.000366
# 8        0.523489      0.005000         0.023605        0.000456
# 25       0.245188      0.002473         0.010086        0.000151
# 9        0.133574      0.008191         0.005942        0.000138
# 6        0.143376      0.000894         0.006643        0.000134
#
#    param_criterion param_max_depth param_n_estimators  \
# 12            gini               5                 55
# 14            gini               5                201
# 10            gini              10                101
# 29         entropy               5                201
# 7             gini              12                101
# 24         entropy              10                 55
# 26         entropy              10                201
# 8             gini              12                201
# 25         entropy              10                101
# 9             gini              10                 55
# 6             gini              12                 55
#
#                                                params  split0_test_score  \
# 12  {'criterion': 'gini', 'max_depth': 5, 'n_estim...           0.535907
# 14  {'criterion': 'gini', 'max_depth': 5, 'n_estim...           0.544402
# 10  {'criterion': 'gini', 'max_depth': 10, 'n_esti...           0.511969
# 29  {'criterion': 'entropy', 'max_depth': 5, 'n_es...           0.529730
# 7   {'criterion': 'gini', 'max_depth': 12, 'n_esti...           0.528185
# 24  {'criterion': 'entropy', 'max_depth': 10, 'n_e...           0.508880
# 26  {'criterion': 'entropy', 'max_depth': 10, 'n_e...           0.511969
# 8   {'criterion': 'gini', 'max_depth': 12, 'n_esti...           0.515830
# 25  {'criterion': 'entropy', 'max_depth': 10, 'n_e...           0.524324
# 9   {'criterion': 'gini', 'max_depth': 10, 'n_esti...           0.513514
# 6   {'criterion': 'gini', 'max_depth': 12, 'n_esti...           0.515058
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 12           0.514683           0.528594           0.515456
# 14           0.513138           0.524730           0.502318
# 10           0.512365           0.520093           0.527821
# 29           0.516229           0.514683           0.513910
# 7            0.507728           0.523957           0.523957
# 24           0.513910           0.534776           0.514683
# 26           0.511592           0.520866           0.513138
# 8            0.504637           0.527821           0.522411
# 25           0.513138           0.534776           0.503091
# 9            0.513138           0.527048           0.522411
# 6            0.506955           0.512365           0.532457
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 12           0.554869         0.529902        0.014842                1
# 14           0.536321         0.524182        0.015209                2
# 10           0.546368         0.523723        0.012727                3
# 29           0.535549         0.522020        0.008895                4
# 7            0.523957         0.521557        0.007106                5
# 24           0.534776         0.521405        0.011098                6
# 26           0.543277         0.520168        0.012039                7
# 8            0.530139         0.520168        0.009198                8
# 25           0.525502         0.520166        0.010956                9
# 9            0.520866         0.519395        0.005359               10
# 6            0.530139         0.519395        0.010090               11

# %% [markdown]
# ## RFC grid_search CROSS_VALIDATION PLAYTIME

# %%
param_grid = {
    'max_depth': [5,8,10, 12,15],
    'n_estimators': [31, 55, 101,201,501],
    'criterion': ['gini', 'entropy'],
    'oob_score':['False','True']
}
gr_search = GridSearchCV(RandomForestClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 8, 10, 12, 15],
#                          'n_estimators': [31, 55, 101, 201, 501],
#                          'oob_score': ['False', 'True']})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 8, 10, 12, 15],
#                          'n_estimators': [31, 55, 101, 201, 501],
#                          'oob_score': ['False', 'True']})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (100, 17)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head(11)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 51       0.058927      0.003090         0.002468        0.000107
# 7        0.346849      0.012091         0.013209        0.000259
# 10       0.073657      0.002771         0.003125        0.000076
# 9        0.906204      0.041024         0.032039        0.000684
# 67       0.483511      0.015460         0.016554        0.000327
# 59       0.925430      0.045532         0.031308        0.000606
# 85       0.322484      0.001129         0.011593        0.000220
# 55       0.178180      0.000463         0.006740        0.000093
# 58       0.876541      0.003787         0.031233        0.000430
# 4        0.173993      0.000774         0.006868        0.000149
# 18       1.094978      0.003175         0.042754        0.000685
#
#    param_criterion param_max_depth param_n_estimators param_oob_score  \
# 51         entropy               5                 31            True
# 7             gini               5                201            True
# 10            gini               8                 31           False
# 9             gini               5                501            True
# 67         entropy               8                201            True
# 59         entropy               5                501            True
# 85         entropy              12                101            True
# 55         entropy               5                101            True
# 58         entropy               5                501           False
# 4             gini               5                101           False
# 18            gini               8                501           False
#
#                                                params  split0_test_score  \
# 51  {'criterion': 'entropy', 'max_depth': 5, 'n_es...           0.542857
# 7   {'criterion': 'gini', 'max_depth': 5, 'n_estim...           0.528185
# 10  {'criterion': 'gini', 'max_depth': 8, 'n_estim...           0.526641
# 9   {'criterion': 'gini', 'max_depth': 5, 'n_estim...           0.530502
# 67  {'criterion': 'entropy', 'max_depth': 8, 'n_es...           0.536680
# 59  {'criterion': 'entropy', 'max_depth': 5, 'n_es...           0.538996
# 85  {'criterion': 'entropy', 'max_depth': 12, 'n_e...           0.520463
# 55  {'criterion': 'entropy', 'max_depth': 5, 'n_es...           0.528958
# 58  {'criterion': 'entropy', 'max_depth': 5, 'n_es...           0.532046
# 4   {'criterion': 'gini', 'max_depth': 5, 'n_estim...           0.535135
# 18  {'criterion': 'gini', 'max_depth': 8, 'n_estim...           0.535135
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 51           0.532457           0.518547           0.517002
# 7            0.500773           0.539413           0.521638
# 10           0.510046           0.528594           0.517774
# 9            0.511592           0.533230           0.517002
# 67           0.513910           0.520093           0.523184
# 59           0.516229           0.530912           0.506955
# 85           0.517774           0.523957           0.513138
# 55           0.517774           0.527048           0.515456
# 58           0.517774           0.521638           0.515456
# 4            0.510046           0.525502           0.513138
# 18           0.510046           0.525502           0.516229
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 51           0.531685         0.528510        0.009625                1
# 7            0.541731         0.526348        0.014744                2
# 10           0.544822         0.525575        0.011685                3
# 9            0.535549         0.525575        0.009501                4
# 67           0.533230         0.525419        0.008410                5
# 59           0.533230         0.525264        0.011839                6
# 85           0.548686         0.524804        0.012453                7
# 55           0.534003         0.524648        0.006980                8
# 58           0.534003         0.524184        0.007510                9
# 4            0.537094         0.524183        0.011048               10
# 18           0.534003         0.524183        0.009811               10

# %% [markdown]
# ## NBC grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'var_smoothing': [.000000001,.000000002,.000000003]
}
gr_search = GridSearchCV(GaussianNB(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=GaussianNB(),
#              param_grid={'var_smoothing': [1e-09, 2e-09, 3e-09]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=GaussianNB(),
#              param_grid={'var_smoothing': [1e-09, 2e-09, 3e-09]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (3, 14)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.003777      0.000639         0.001732        0.000203
# 1       0.002515      0.000264         0.001106        0.000112
# 2       0.001809      0.000260         0.000959        0.000163
#
#   param_var_smoothing                    params  split0_test_score  \
# 0                 0.0  {'var_smoothing': 1e-09}            0.51583
# 1                 0.0  {'var_smoothing': 2e-09}            0.51583
# 2                 0.0  {'var_smoothing': 3e-09}            0.51583
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.503091           0.522411           0.512365           0.532457
# 1           0.503091           0.522411           0.512365           0.532457
# 2           0.503091           0.522411           0.512365           0.532457
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.517231        0.009841                1
# 1         0.517231        0.009841                1
# 2         0.517231        0.009841                1

# %% [markdown]
# ## GBC grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'learning_rate': [0.1,0.2,0.5,1.0, 5.0],
    'n_estimators': [55, 101, 201],
    'min_samples_leaf': [1,5,10,20],
}
gr_search = GridSearchCV(GradientBoostingClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.1, 0.2, 0.5, 1.0, 5.0],
#                          'min_samples_leaf': [1, 5, 10, 20],
#                          'n_estimators': [55, 101, 201]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.1, 0.2, 0.5, 1.0, 5.0],
#                          'min_samples_leaf': [1, 5, 10, 20],
#                          'n_estimators': [55, 101, 201]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (60, 16)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 3        0.157495      0.000275         0.001107        0.000030
# 0        0.167212      0.012252         0.001120        0.000076
# 15       0.163812      0.000290         0.001144        0.000015
# 4        0.292702      0.003608         0.001588        0.000023
# 7        0.299272      0.001006         0.001682        0.000070
#
#    param_learning_rate param_min_samples_leaf param_n_estimators  \
# 3                  0.1                      5                 55
# 0                  0.1                      1                 55
# 15                 0.2                      5                 55
# 4                  0.1                      5                101
# 7                  0.1                     10                101
#
#                                                params  split0_test_score  \
# 3   {'learning_rate': 0.1, 'min_samples_leaf': 5, ...           0.528958
# 0   {'learning_rate': 0.1, 'min_samples_leaf': 1, ...           0.520463
# 15  {'learning_rate': 0.2, 'min_samples_leaf': 5, ...           0.500386
# 4   {'learning_rate': 0.1, 'min_samples_leaf': 5, ...           0.522780
# 7   {'learning_rate': 0.1, 'min_samples_leaf': 10,...           0.529730
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 3            0.527821           0.512365           0.509274
# 0            0.522411           0.510819           0.523184
# 15           0.531685           0.517774           0.518547
# 4            0.522411           0.516229           0.517774
# 7            0.519320           0.513910           0.502318
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 3            0.532457         0.522175        0.009448                1
# 0            0.529366         0.521249        0.006006                2
# 15           0.524730         0.518624        0.010404                3
# 4            0.513910         0.518621        0.003473                4
# 7            0.521638         0.517383        0.009092                5

# %% [markdown]
# ## GBC grid_search CROSS_VALIDATION PLAYTIME

# %%
param_grid = {
    'learning_rate': [0.02,0.05,0.1],
    'n_estimators': [21,31,55, 101],
    'min_samples_leaf': [2,5,10],
}
gr_search = GridSearchCV(GradientBoostingClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.02, 0.05, 0.1],
#                          'min_samples_leaf': [2, 5, 10],
#                          'n_estimators': [21, 31, 55, 101]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.02, 0.05, 0.1],
#                          'min_samples_leaf': [2, 5, 10],
#                          'n_estimators': [21, 31, 55, 101]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (36, 16)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 29       0.092557      0.000217         0.000886        0.000021
# 13       0.092020      0.000475         0.000906        0.000015
# 12       0.062574      0.000109         0.000786        0.000015
# 24       0.062509      0.000109         0.000771        0.000009
# 18       0.162073      0.000207         0.001152        0.000037
#
#    param_learning_rate param_min_samples_leaf param_n_estimators  \
# 29                 0.1                      5                 31
# 13                0.05                      2                 31
# 12                0.05                      2                 21
# 24                 0.1                      2                 21
# 18                0.05                      5                 55
#
#                                                params  split0_test_score  \
# 29  {'learning_rate': 0.1, 'min_samples_leaf': 5, ...           0.531274
# 13  {'learning_rate': 0.05, 'min_samples_leaf': 2,...           0.538996
# 12  {'learning_rate': 0.05, 'min_samples_leaf': 2,...           0.537452
# 24  {'learning_rate': 0.1, 'min_samples_leaf': 2, ...           0.532819
# 18  {'learning_rate': 0.05, 'min_samples_leaf': 5,...           0.532819
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 29           0.515456           0.523957           0.513138
# 13           0.519320           0.513910           0.509274
# 12           0.508501           0.522411           0.508501
# 24           0.517002           0.523184           0.506955
# 18           0.517002           0.513910           0.517002
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 29           0.537867         0.524338        0.009334                1
# 13           0.538640         0.524028        0.012488                2
# 12           0.541731         0.523719        0.013985                3
# 24           0.537094         0.523411        0.010841                4
# 18           0.534003         0.522947        0.008626                5

# %% [markdown]
# ## CATboost grid_search CROSS_VALIDATION k=5

# %%
# Create and fit the thing
CATb = CatBoostClassifier(verbose=False,depth=10,learning_rate=1.0)
CATb.fit(X_train,y_train)
CATb_preds = CATb.predict(X_train)
pd.crosstab(CATb_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         3167     7
# 1           13  3284

# %%
print(f'Accuracy-Train {round(CATb.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(CATb.score(X_validate,y_validate),4)}')
print(classification_report(y_train,CATb_preds))
print(classification_report(y_validate,CATb.predict(X_validate)))
# Out:
# Accuracy-Train 0.9969
# Accuracy-Validate 0.4992
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3180
#            1       1.00      1.00      1.00      3291
#
#     accuracy                           1.00      6471
#    macro avg       1.00      1.00      1.00      6471
# weighted avg       1.00      1.00      1.00      6471
#
#               precision    recall  f1-score   support
#
#            0       0.49      0.51      0.50      1178
#            1       0.51      0.49      0.50      1216
#
#     accuracy                           0.50      2394
#    macro avg       0.50      0.50      0.50      2394
# weighted avg       0.50      0.50      0.50      2394

# %%
param_grid = {
    'verbose': [False],
    'depth': [5, 10, 12],
    'learning_rate': [0.1,0.2, 0.5],
}
gr_search = GridSearchCV(CatBoostClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=<catboost.core.CatBoostClassifier object at 0x169de2730>,
#              param_grid={'depth': [5, 10, 12], 'learning_rate': [0.1, 0.2, 0.5],
#                          'verbose': [False]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=<catboost.core.CatBoostClassifier object at 0x169de2730>,
#              param_grid={'depth': [5, 10, 12], 'learning_rate': [0.1, 0.2, 0.5],
#                          'verbose': [False]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (9, 16)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_depth  \
# 6       7.103155      0.022825         0.002310        0.000020          12
# 3       2.824779      0.002587         0.001629        0.000014          10
# 1       1.246808      0.007507         0.001098        0.000214           5
# 0       1.257302      0.013522         0.001209        0.000214           5
# 7       7.093312      0.036170         0.002278        0.000023          12
#
#   param_learning_rate param_verbose  \
# 6                 0.1         False
# 3                 0.1         False
# 1                 0.2         False
# 0                 0.1         False
# 7                 0.2         False
#
#                                               params  split0_test_score  \
# 6  {'depth': 12, 'learning_rate': 0.1, 'verbose':...           0.507336
# 3  {'depth': 10, 'learning_rate': 0.1, 'verbose':...           0.510425
# 1  {'depth': 5, 'learning_rate': 0.2, 'verbose': ...           0.522008
# 0  {'depth': 5, 'learning_rate': 0.1, 'verbose': ...           0.516602
# 7  {'depth': 12, 'learning_rate': 0.2, 'verbose':...           0.494208
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 6           0.524730           0.520866           0.514683           0.524730
# 3           0.506182           0.519320           0.513910           0.527048
# 1           0.510819           0.506182           0.508501           0.518547
# 0           0.506182           0.504637           0.500773           0.528594
# 7           0.517774           0.512365           0.516229           0.514683
#
#    mean_test_score  std_test_score  rank_test_score
# 6         0.518469        0.006669                1
# 3         0.515377        0.007252                2
# 1         0.513211        0.006053                3
# 0         0.511358        0.010085                4
# 7         0.511052        0.008609                5

# %% [markdown]
# ## SCALE for Logistic regression, MLP, etc.

# %%
sc_X = StandardScaler()
X_train_scaled = sc_X.fit_transform(X_train)
X_validate_scaled = sc_X.transform(X_validate)
X_test_scaled = sc_X.transform(X_test)

# %%
mlp = MLPClassifier(hidden_layer_sizes=(1024,512,128),activation="relu",random_state=2013,
                    batch_size=200,solver='adam')
mlp.fit(X_train_scaled, y_train)
mlp_preds = mlp.predict(X_train_scaled)
print(mlp.score(X_train_scaled, y_train))
pd.crosstab(mlp_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# 0.9313861845155308
# is_under     0     1
# row_0
# 0         3025   289
# 1          155  3002

# %%
mlp.n_layers_
# Out:
# 5

# %%
print(f'Accuracy-Train {round(mlp.score(X_train_scaled,y_train),4)}')
print(f'Accuracy-Validate {round(mlp.score(X_validate_scaled,y_validate),4)}')
print(classification_report(y_train,mlp_preds))
print(classification_report(y_validate,mlp.predict(X_validate_scaled)))
# Out:
# Accuracy-Train 0.9314
# Accuracy-Validate 0.5004
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      3180
#            1       0.95      0.91      0.93      3291
#
#     accuracy                           0.93      6471
#    macro avg       0.93      0.93      0.93      6471
# weighted avg       0.93      0.93      0.93      6471
#
#               precision    recall  f1-score   support
#
#            0       0.49      0.53      0.51      1178
#            1       0.51      0.47      0.49      1216
#
#     accuracy                           0.50      2394
#    macro avg       0.50      0.50      0.50      2394
# weighted avg       0.50      0.50      0.50      2394

# %% [markdown]
# ## KNN grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'n_neighbors': [70],
    'weights': ['uniform','distance'],
    'algorithm':['ball_tree','brute'],
    'leaf_size': [3,4,5,6,7,8,9],
}
gr_search = GridSearchCV(KNeighborsClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['ball_tree', 'brute'],
#                          'leaf_size': [3, 4, 5, 6, 7, 8, 9],
#                          'n_neighbors': [70],
#                          'weights': ['uniform', 'distance']})

# %%
gr_search.fit(X_train, y_train)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['ball_tree', 'brute'],
#                          'leaf_size': [3, 4, 5, 6, 7, 8, 9],
#                          'n_neighbors': [70],
#                          'weights': ['uniform', 'distance']})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (28, 17)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head(31)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 27       0.000815      0.000027         0.024602        0.000997
# 25       0.001038      0.000434         0.025845        0.001295
# 23       0.000836      0.000042         0.024377        0.001117
# 21       0.000841      0.000044         0.024959        0.001190
# 19       0.000802      0.000025         0.025585        0.001902
# 17       0.000812      0.000021         0.025371        0.001381
# 15       0.000819      0.000021         0.025109        0.001028
# 1        0.002290      0.000040         0.046682        0.000665
# 3        0.002274      0.000034         0.046734        0.000640
# 5        0.002275      0.000031         0.046698        0.000615
# 11       0.002077      0.000009         0.043003        0.000721
# 13       0.002081      0.000006         0.042973        0.000742
# 9        0.002092      0.000018         0.043036        0.000695
# 7        0.002075      0.000019         0.043019        0.000671
# 26       0.000862      0.000020         0.032549        0.002318
# 14       0.000878      0.000103         0.033633        0.004124
# 16       0.000820      0.000044         0.031674        0.001206
# 18       0.000862      0.000115         0.030848        0.000359
# 20       0.000889      0.000100         0.033566        0.002899
# 22       0.000813      0.000037         0.033185        0.002902
# 24       0.000878      0.000093         0.033480        0.002424
# 12       0.002079      0.000008         0.048766        0.000702
# 8        0.002083      0.000020         0.048936        0.000624
# 6        0.002095      0.000049         0.048905        0.000691
# 10       0.002069      0.000013         0.048954        0.000714
# 4        0.002315      0.000069         0.053041        0.001422
# 2        0.002240      0.000015         0.052635        0.000798
# 0        0.003406      0.002089         0.059053        0.013049
#
#    param_algorithm param_leaf_size param_n_neighbors param_weights  \
# 27           brute               9                70      distance
# 25           brute               8                70      distance
# 23           brute               7                70      distance
# 21           brute               6                70      distance
# 19           brute               5                70      distance
# 17           brute               4                70      distance
# 15           brute               3                70      distance
# 1        ball_tree               3                70      distance
# 3        ball_tree               4                70      distance
# 5        ball_tree               5                70      distance
# 11       ball_tree               8                70      distance
# 13       ball_tree               9                70      distance
# 9        ball_tree               7                70      distance
# 7        ball_tree               6                70      distance
# 26           brute               9                70       uniform
# 14           brute               3                70       uniform
# 16           brute               4                70       uniform
# 18           brute               5                70       uniform
# 20           brute               6                70       uniform
# 22           brute               7                70       uniform
# 24           brute               8                70       uniform
# 12       ball_tree               9                70       uniform
# 8        ball_tree               7                70       uniform
# 6        ball_tree               6                70       uniform
# 10       ball_tree               8                70       uniform
# 4        ball_tree               5                70       uniform
# 2        ball_tree               4                70       uniform
# 0        ball_tree               3                70       uniform
#
#                                                params  split0_test_score  \
# 27  {'algorithm': 'brute', 'leaf_size': 9, 'n_neig...           0.535135
# 25  {'algorithm': 'brute', 'leaf_size': 8, 'n_neig...           0.535135
# 23  {'algorithm': 'brute', 'leaf_size': 7, 'n_neig...           0.535135
# 21  {'algorithm': 'brute', 'leaf_size': 6, 'n_neig...           0.535135
# 19  {'algorithm': 'brute', 'leaf_size': 5, 'n_neig...           0.535135
# 17  {'algorithm': 'brute', 'leaf_size': 4, 'n_neig...           0.535135
# 15  {'algorithm': 'brute', 'leaf_size': 3, 'n_neig...           0.535135
# 1   {'algorithm': 'ball_tree', 'leaf_size': 3, 'n_...           0.534363
# 3   {'algorithm': 'ball_tree', 'leaf_size': 4, 'n_...           0.534363
# 5   {'algorithm': 'ball_tree', 'leaf_size': 5, 'n_...           0.534363
# 11  {'algorithm': 'ball_tree', 'leaf_size': 8, 'n_...           0.533591
# 13  {'algorithm': 'ball_tree', 'leaf_size': 9, 'n_...           0.533591
# 9   {'algorithm': 'ball_tree', 'leaf_size': 7, 'n_...           0.533591
# 7   {'algorithm': 'ball_tree', 'leaf_size': 6, 'n_...           0.533591
# 26  {'algorithm': 'brute', 'leaf_size': 9, 'n_neig...           0.531274
# 14  {'algorithm': 'brute', 'leaf_size': 3, 'n_neig...           0.531274
# 16  {'algorithm': 'brute', 'leaf_size': 4, 'n_neig...           0.531274
# 18  {'algorithm': 'brute', 'leaf_size': 5, 'n_neig...           0.531274
# 20  {'algorithm': 'brute', 'leaf_size': 6, 'n_neig...           0.531274
# 22  {'algorithm': 'brute', 'leaf_size': 7, 'n_neig...           0.531274
# 24  {'algorithm': 'brute', 'leaf_size': 8, 'n_neig...           0.531274
# 12  {'algorithm': 'ball_tree', 'leaf_size': 9, 'n_...           0.531274
# 8   {'algorithm': 'ball_tree', 'leaf_size': 7, 'n_...           0.531274
# 6   {'algorithm': 'ball_tree', 'leaf_size': 6, 'n_...           0.531274
# 10  {'algorithm': 'ball_tree', 'leaf_size': 8, 'n_...           0.531274
# 4   {'algorithm': 'ball_tree', 'leaf_size': 5, 'n_...           0.532819
# 2   {'algorithm': 'ball_tree', 'leaf_size': 4, 'n_...           0.532819
# 0   {'algorithm': 'ball_tree', 'leaf_size': 3, 'n_...           0.532819
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 27           0.510819           0.509274           0.545595
# 25           0.510819           0.509274           0.545595
# 23           0.510819           0.509274           0.545595
# 21           0.510819           0.509274           0.545595
# 19           0.510819           0.509274           0.545595
# 17           0.510819           0.509274           0.545595
# 15           0.510819           0.509274           0.545595
# 1            0.510819           0.510046           0.544822
# 3            0.510819           0.510046           0.544822
# 5            0.510819           0.510046           0.544822
# 11           0.510819           0.507728           0.545595
# 13           0.510819           0.507728           0.545595
# 9            0.510819           0.507728           0.545595
# 7            0.510819           0.507728           0.545595
# 26           0.489954           0.504637           0.528594
# 14           0.489954           0.504637           0.528594
# 16           0.489954           0.504637           0.528594
# 18           0.489954           0.504637           0.528594
# 20           0.489954           0.504637           0.528594
# 22           0.489954           0.504637           0.528594
# 24           0.489954           0.504637           0.528594
# 12           0.489954           0.498454           0.527821
# 8            0.489954           0.498454           0.527821
# 6            0.489954           0.498454           0.527821
# 10           0.489954           0.498454           0.527821
# 4            0.486862           0.502318           0.526275
# 2            0.486862           0.502318           0.526275
# 0            0.486862           0.502318           0.526275
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 27           0.533230         0.526811        0.014329                1
# 25           0.533230         0.526811        0.014329                1
# 23           0.533230         0.526811        0.014329                1
# 21           0.533230         0.526811        0.014329                1
# 19           0.533230         0.526811        0.014329                1
# 17           0.533230         0.526811        0.014329                1
# 15           0.533230         0.526811        0.014329                1
# 1            0.531685         0.526347        0.013718                8
# 3            0.531685         0.526347        0.013718                8
# 5            0.531685         0.526347        0.013718                8
# 11           0.533230         0.526193        0.014546               11
# 13           0.533230         0.526193        0.014546               11
# 9            0.533230         0.526193        0.014546               11
# 7            0.533230         0.526193        0.014546               11
# 26           0.523184         0.515528        0.015811               15
# 14           0.523184         0.515528        0.015811               15
# 16           0.523184         0.515528        0.015811               15
# 18           0.523184         0.515528        0.015811               15
# 20           0.523184         0.515528        0.015811               15
# 22           0.523184         0.515528        0.015811               15
# 24           0.523184         0.515528        0.015811               15
# 12           0.525502         0.514601        0.016969               22
# 8            0.525502         0.514601        0.016969               22
# 6            0.525502         0.514601        0.016969               22
# 10           0.525502         0.514601        0.016969               22
# 4            0.524730         0.514601        0.017269               26
# 2            0.524730         0.514601        0.017269               26
# 0            0.524730         0.514601        0.017269               26

# %% [markdown]
# ## LOG grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'penalty': ['none','l1','l2','elasticnet'],
    'class_weight': ['balanced',None],
    'max_iter':[100,50,200]
}
gr_search = GridSearchCV(LogisticRegression(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'class_weight': ['balanced', None],
#                          'max_iter': [100, 50, 200],
#                          'penalty': ['none', 'l1', 'l2', 'elasticnet']})

# %%
gr_search.fit(X_train, y_train)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1091, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 61, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1091, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 61, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.51599351        nan 0.51228503        nan 0.5163037         nan
#  0.51135792        nan 0.51491278        nan 0.51661222        nan
#  0.51383075        nan 0.51413975        nan 0.51692194        nan
#  0.51614962        nan 0.51846718        nan 0.51924081        nan]
#   warnings.warn(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'class_weight': ['balanced', None],
#                          'max_iter': [100, 50, 200],
#                          'penalty': ['none', 'l1', 'l2', 'elasticnet']})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (24, 16)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head(11)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 22       0.057396      0.003589         0.001049        0.000450
# 20       0.080129      0.028183         0.000992        0.000355
# 16       0.016354      0.001976         0.000778        0.000360
# 10       0.072022      0.011972         0.000867        0.000333
# 4        0.016908      0.002160         0.000904        0.000322
# 18       0.017405      0.004808         0.001761        0.001781
# 0        0.041363      0.017243         0.001038        0.000734
# 8        0.063580      0.005083         0.000760        0.000488
# 14       0.037548      0.010172         0.001131        0.000543
# 12       0.031367      0.006145         0.000902        0.000350
# 2        0.031347      0.004608         0.001305        0.001300
#
#    param_class_weight param_max_iter param_penalty  \
# 22               None            200            l2
# 20               None            200          none
# 16               None             50          none
# 10           balanced            200            l2
# 4            balanced             50          none
# 18               None             50            l2
# 0            balanced            100          none
# 8            balanced            200          none
# 14               None            100            l2
# 12               None            100          none
# 2            balanced            100            l2
#
#                                                params  split0_test_score  \
# 22  {'class_weight': None, 'max_iter': 200, 'penal...           0.511969
# 20  {'class_weight': None, 'max_iter': 200, 'penal...           0.517375
# 16  {'class_weight': None, 'max_iter': 50, 'penalt...           0.515058
# 10  {'class_weight': 'balanced', 'max_iter': 200, ...           0.518919
# 4   {'class_weight': 'balanced', 'max_iter': 50, '...           0.515058
# 18  {'class_weight': None, 'max_iter': 50, 'penalt...           0.511969
# 0   {'class_weight': 'balanced', 'max_iter': 100, ...           0.522008
# 8   {'class_weight': 'balanced', 'max_iter': 200, ...           0.514286
# 14  {'class_weight': None, 'max_iter': 100, 'penal...           0.515830
# 12  {'class_weight': None, 'max_iter': 100, 'penal...           0.515058
# 2   {'class_weight': 'balanced', 'max_iter': 100, ...           0.515830
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 22           0.517774           0.528594           0.510046
# 20           0.519320           0.521638           0.513138
# 16           0.509274           0.517002           0.512365
# 10           0.502318           0.523957           0.518547
# 4            0.514683           0.517774           0.516229
# 18           0.506955           0.517774           0.513138
# 0            0.503091           0.513138           0.513138
# 8            0.504637           0.520093           0.522411
# 14           0.504637           0.516229           0.514683
# 12           0.503864           0.519320           0.510046
# 2            0.509274           0.510046           0.508501
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 22           0.527821         0.519241        0.007754                1
# 20           0.520866         0.518467        0.003038                2
# 16           0.530912         0.516922        0.007463                3
# 10           0.519320         0.516612        0.007412                4
# 4            0.517774         0.516304        0.001305                5
# 18           0.530912         0.516150        0.008144                6
# 0            0.528594         0.515994        0.008692                7
# 8            0.513138         0.514913        0.006200                8
# 14           0.519320         0.514140        0.004993                9
# 12           0.520866         0.513831        0.006242               10
# 2            0.517774         0.512285        0.003771               11

# %% [markdown]
# ## SVM grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'shrinking': [True,False],
    'C':[1,5,10]
}
gr_search = GridSearchCV(SVC(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 5, 10], 'shrinking': [True, False]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 5, 10], 'shrinking': [True, False]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (6, 15)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head(11)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 4       0.414090      0.007729         0.218587        0.001134      10
# 5       0.416331      0.004727         0.218645        0.001001      10
# 2       0.403883      0.002031         0.219164        0.000833       5
# 3       0.403963      0.001606         0.219194        0.000811       5
# 0       0.408337      0.017755         0.220756        0.000832       1
# 1       0.396672      0.000548         0.220130        0.001242       1
#
#   param_shrinking                         params  split0_test_score  \
# 4            True   {'C': 10, 'shrinking': True}           0.528185
# 5           False  {'C': 10, 'shrinking': False}           0.528185
# 2            True    {'C': 5, 'shrinking': True}           0.532046
# 3           False   {'C': 5, 'shrinking': False}           0.532046
# 0            True    {'C': 1, 'shrinking': True}           0.528958
# 1           False   {'C': 1, 'shrinking': False}           0.528958
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 4           0.508501           0.525502           0.502318           0.544822
# 5           0.508501           0.525502           0.502318           0.544049
# 2           0.500773           0.523184           0.500000           0.539413
# 3           0.500773           0.523184           0.500000           0.539413
# 0           0.495363           0.504637           0.506955           0.539413
# 1           0.495363           0.504637           0.506955           0.539413
#
#    mean_test_score  std_test_score  rank_test_score
# 4         0.521866        0.015106                1
# 5         0.521711        0.014872                2
# 2         0.519083        0.016110                3
# 3         0.519083        0.016110                3
# 0         0.515065        0.016422                5
# 1         0.515065        0.016422                5

# %% [markdown]
# # NOW return to single iterations of each model with optimized hyperparameters.

# %% [markdown]
# ### RFC: entropy, max_d=5,n_est=55

# %%
# create the Random Forest model 
rf1 = RandomForestClassifier(criterion='entropy',n_estimators=55,max_depth=5)
# fit the model to the TRAIN dataset1
rf1.fit(X_train, y_train)
# use the model by calling for the predictions made via the TRAIN dataset
rf1_preds = rf1.predict(X_train)
pd.crosstab(rf1_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         1838  1293
# 1         1342  1998

# %%
print(f'Accuracy-Train {round(rf1.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(rf1.score(X_validate,y_validate),4)}')
print(classification_report(y_train,rf1_preds))
print(classification_report(y_validate,rf1.predict(X_validate)))
# Out:
# Accuracy-Train 0.5928
# Accuracy-Validate 0.5104
#               precision    recall  f1-score   support
#
#            0       0.59      0.58      0.58      3180
#            1       0.60      0.61      0.60      3291
#
#     accuracy                           0.59      6471
#    macro avg       0.59      0.59      0.59      6471
# weighted avg       0.59      0.59      0.59      6471
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.48      0.49      1178
#            1       0.52      0.54      0.53      1216
#
#     accuracy                           0.51      2394
#    macro avg       0.51      0.51      0.51      2394
# weighted avg       0.51      0.51      0.51      2394

# %% [markdown]
# ### KNN: n_neighbors=70, "distance" based weighting ,"brute" computation

# %%
knn = KNeighborsClassifier(n_neighbors=70,weights='distance',algorithm='brute')
knn.fit(X_train_scaled, y_train)
knn_preds = knn.predict(X_train_scaled)
print(knn.score(X_train_scaled, y_train))
pd.crosstab(knn_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# 0.9969092875907897
# is_under     0     1
# row_0
# 0         3180    20
# 1            0  3271

# %%
print(f'Accuracy-Train {round(knn.score(X_train_scaled,y_train),4)}')
print(f'Accuracy-Validate {round(knn.score(X_validate_scaled,y_validate),4)}')
print(classification_report(y_train,knn_preds))
print(classification_report(y_validate,knn.predict(X_validate_scaled)))
# Out:
# Accuracy-Train 0.9969
# Accuracy-Validate 0.5
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3180
#            1       1.00      0.99      1.00      3291
#
#     accuracy                           1.00      6471
#    macro avg       1.00      1.00      1.00      6471
# weighted avg       1.00      1.00      1.00      6471
#
#               precision    recall  f1-score   support
#
#            0       0.49      0.46      0.48      1178
#            1       0.51      0.53      0.52      1216
#
#     accuracy                           0.50      2394
#    macro avg       0.50      0.50      0.50      2394
# weighted avg       0.50      0.50      0.50      2394

# %% [markdown]
# ### GBC: learning_rate=0.05, n_est=31,min_samples_leaf=2

# %%
# create the Random Forest model 
gbc = GradientBoostingClassifier(learning_rate=0.05,n_estimators=31,min_samples_leaf=2)
# fit the model to the TRAIN dataset:
gbc.fit(X_train, y_train)
# use the model by calling for the predictions made via the TRAIN dataset
gbc_preds = gbc.predict(X_train)
pd.crosstab(gbc_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         1646  1346
# 1         1534  1945

# %%
print(f'Accuracy-Train {round(gbc.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(gbc.score(X_validate,y_validate),4)}')
print(classification_report(y_train,gbc_preds))
print(classification_report(y_validate,gbc.predict(X_validate)))
# Out:
# Accuracy-Train 0.5549
# Accuracy-Validate 0.5038
#               precision    recall  f1-score   support
#
#            0       0.55      0.52      0.53      3180
#            1       0.56      0.59      0.57      3291
#
#     accuracy                           0.55      6471
#    macro avg       0.55      0.55      0.55      6471
# weighted avg       0.55      0.55      0.55      6471
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.46      0.48      1178
#            1       0.51      0.55      0.53      1216
#
#     accuracy                           0.50      2394
#    macro avg       0.50      0.50      0.50      2394
# weighted avg       0.50      0.50      0.50      2394

# %%
cols = X_train.columns

# %%
cols
# Out:
# Index(['week_num', 'temp', 'humidity', 'wind', 'spread', 'ou',
#        'abnormal_start', 'is_playoff', 'playoff_implications', 'is_turf',
#        'is_outdoor'],
#       dtype='object')

# %%
gini = gbc.feature_importances_

# %%
gini
# Out:
# array([0.07565601, 0.24076834, 0.11100929, 0.28817275, 0.06482177,
#        0.12492188, 0.0238728 , 0.        , 0.02971773, 0.04105943,
#        0.        ])

# %%
feat_df = pd.DataFrame({'Feature':cols, 'Coef':gini})

# %%
feat_df.sort_values('Coef',ascending=False)
# Out:
#                  Feature      Coef
# 3                   wind  0.288173
# 1                   temp  0.240768
# 5                     ou  0.124922
# 2               humidity  0.111009
# 0               week_num  0.075656
# 4                 spread  0.064822
# 9                is_turf  0.041059
# 8   playoff_implications  0.029718
# 6         abnormal_start  0.023873
# 7             is_playoff  0.000000
# 10            is_outdoor  0.000000
