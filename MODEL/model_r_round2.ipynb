# %%
#standard ds imports
import pandas as pd
import numpy as np
#viz and stats
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# .py imports
#import wranglerer as wr
#import modeling as md
import os
#sklearn imports
from sklearn.model_selection import train_test_split,cross_val_score, GridSearchCV
import sklearn.preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix, plot_confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
#CATboost imports
from catboost import CatBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
import explore_r as ex
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %% [markdown]
# ### This notebook builds upon the previous notebook (model_r) and incorporates GridSearch CrossValidation to explore each algorithm with a small subset of possible hyperparameter combinations.

# %%
df = pd.read_csv('prepped_data.csv')

# %%
df = df.drop(columns=['date', 'day_of_week', 'start_time','home_score',
       'home_wins', 'away_score', 'away_wins','total_scores'])
df['spread'] = abs(df['spread'])

# %%
df.head()
# Out:
#    week_num                          stadium  temp  humidity  wind  spread  \
# 0        19               State Farm Stadium    72         0     0     1.0
# 1        19          Lincoln Financial Field    52        48    14     2.5
# 2        19  GEHA Field at Arrowhead Stadium    22        55    13     1.5
# 3        19                 Highmark Stadium    32        10     0     5.5
# 4        19                   Levi's Stadium    55        47    19     4.0
#
#      ou  is_under  abnormal_start  is_playoff  playoff_implications  is_turf  \
# 0  51.0         0               0           1                     1        0
# 1  45.5         1               0           1                     1        0
# 2  48.0         1               0           1                     1        0
# 3  49.0         1               0           1                     1        1
# 4  47.0         1               0           1                     1        0
#
#    is_outdoor
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10811 entries, 0 to 10810
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   week_num              10811 non-null  int64
#  1   stadium               10811 non-null  object
#  2   temp                  10811 non-null  int64
#  3   humidity              10811 non-null  int64
#  4   wind                  10811 non-null  int64
#  5   spread                10811 non-null  float64
#  6   ou                    10811 non-null  float64
#  7   is_under              10811 non-null  int64
#  8   abnormal_start        10811 non-null  int64
#  9   is_playoff            10811 non-null  int64
#  10  playoff_implications  10811 non-null  int64
#  11  is_turf               10811 non-null  int64
#  12  is_outdoor            10811 non-null  int64
# dtypes: float64(2), int64(10), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# ## ESTABLISH BASELINE 50.7%

# %%
df.is_under.value_counts(normalize=True)
# Out:
# 1    0.507354
# 0    0.492646
# Name: is_under, dtype: float64

# %%
df['baseline'] = 1

# %%
baseline_accuracy = (df.baseline == df.is_under).mean()
print(f'baseline accuracy: {baseline_accuracy:.2%}')
# Out:
# baseline accuracy: 50.74%

# %%
subset = df[df.is_under == 1]
baseline_recall = (subset.baseline == subset.is_under).mean()
print(f'baseline recall: {baseline_recall:.2%}')
# Out:
# baseline recall: 100.00%

# %%
subset = df[df.baseline == 1]
baseline_precision = (subset.baseline == subset.is_under).mean()
print(f'baseline precision: {baseline_precision:.2%}')
# Out:
# baseline precision: 50.74%

# %%
df.drop(columns='baseline',inplace=True)

# %%
df_no_stadium = df.drop(columns='stadium')

# %%
df_no_stadium.head()
# Out:
#    week_num  temp  humidity  wind  spread    ou  is_under  abnormal_start  \
# 0        19    72         0     0     1.0  51.0         0               0
# 1        19    52        48    14     2.5  45.5         1               0
# 2        19    22        55    13     1.5  48.0         1               0
# 3        19    32        10     0     5.5  49.0         1               0
# 4        19    55        47    19     4.0  47.0         1               0
#
#    is_playoff  playoff_implications  is_turf  is_outdoor
# 0           1                     1        0           0
# 1           1                     1        0           1
# 2           1                     1        0           1
# 3           1                     1        1           1
# 4           1                     1        0           1

# %%
X_train, y_train, X_validate, y_validate, X_test, y_test = ex.train_validate_test(df_no_stadium,'is_under')

# %%
X_train.shape, y_train.shape, X_validate.shape, y_validate.shape, X_test.shape, y_test.shape
# Out:
# ((6471, 11), (6471,), (2394, 11), (2394,), (1946, 11), (1946,))

# %%
print(y_train.value_counts(normalize=True))
print(y_validate.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# 1    0.50734
# 0    0.49266
# Name: is_under, dtype: float64
# 1    0.507519
# 0    0.492481
# Name: is_under, dtype: float64
# 1    0.507194
# 0    0.492806
# Name: is_under, dtype: float64

# %%
X_train.head()
# Out:
#       week_num  temp  humidity  wind  spread    ou  abnormal_start  \
# 894         14    78        58     9     3.0  46.5               0
# 6913        11    32        73    11     4.0  41.5               0
# 886         14    72         0     0     3.5  48.0               0
# 7630        12    37        49    20    13.0  37.0               0
# 5466         7    81        24     5     3.5  36.5               0
#
#       is_playoff  playoff_implications  is_turf  is_outdoor
# 894            0                     1        0           1
# 6913           0                     1        1           1
# 886            0                     0        1           0
# 7630           0                     1        1           1
# 5466           0                     0        0           1

# %% [markdown]
# # MODELING

# %% [markdown]
# ## DTC VANILLA

# %%
# create the Decision Tree Classifier model 
dtc = DecisionTreeClassifier()

# %%
# fit the model to the TRAIN dataset:
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# use the model by calling for the predictions made via the TRAIN dataset
dtc_preds = dtc.predict(X_train)
pd.crosstab(dtc_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         3188    27
# 1            0  3256

# %%
print(f'Accuracy-Train {round(dtc.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(dtc.score(X_validate,y_validate),4)}')
print(classification_report(y_train,dtc_preds))
print(classification_report(y_validate,dtc.predict(X_validate)))
# Out:
# Accuracy-Train 0.9958
# Accuracy-Validate 0.5084
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3188
#            1       1.00      0.99      1.00      3283
#
#     accuracy                           1.00      6471
#    macro avg       1.00      1.00      1.00      6471
# weighted avg       1.00      1.00      1.00      6471
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.51      1179
#            1       0.52      0.51      0.51      1215
#
#     accuracy                           0.51      2394
#    macro avg       0.51      0.51      0.51      2394
# weighted avg       0.51      0.51      0.51      2394

# %% [markdown]
# ## DTC maxDepth = X

# %%
# create the Decision Tree Classifier model 
dtc = DecisionTreeClassifier(max_depth=5,min_samples_leaf=5)

# %%
# fit the model to the TRAIN dataset:
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=5)

# %%
# use the model by calling for the predictions made via the TRAIN dataset
dtc_preds = dtc.predict(X_train)
pd.crosstab(dtc_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         1428  1221
# 1         1760  2062

# %%
print(f'Accuracy-Train {round(dtc.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(dtc.score(X_validate,y_validate),4)}')
print(classification_report(y_train,dtc_preds))
print(classification_report(y_validate,dtc.predict(X_validate)))
# Out:
# Accuracy-Train 0.5393
# Accuracy-Validate 0.5046
#               precision    recall  f1-score   support
#
#            0       0.54      0.45      0.49      3188
#            1       0.54      0.63      0.58      3283
#
#     accuracy                           0.54      6471
#    macro avg       0.54      0.54      0.53      6471
# weighted avg       0.54      0.54      0.54      6471
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.42      0.46      1179
#            1       0.51      0.58      0.54      1215
#
#     accuracy                           0.50      2394
#    macro avg       0.50      0.50      0.50      2394
# weighted avg       0.50      0.50      0.50      2394

# %% [markdown]
# ## DTC grid_search CROSS_VALIDATION k=5

# %%
cross_val_score(dtc, X_train, y_train, cv=10)
# Out:
# array([0.52006173, 0.52859351, 0.50850077, 0.51313756, 0.48686244,
#        0.48222566, 0.51622875, 0.50695518, 0.52395672, 0.48995363])

# %%
param_grid = {
    'max_depth': [None,18, 12, 10, 5],
    'min_samples_leaf': [1, 5, 10, 20],
    'criterion': ['gini', 'entropy'],
}

# %%
gr_search = GridSearchCV(DecisionTreeClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 18, 12, 10, 5],
#                          'min_samples_leaf': [1, 5, 10, 20]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 18, 12, 10, 5],
#                          'min_samples_leaf': [1, 5, 10, 20]})

# %%
results = gr_search.cv_results_

# %%
results_df_init = pd.DataFrame(results)

# %%
results_df_init.shape
# Out:
# (40, 16)

# %%
params = pd.DataFrame(results['params'])

# %%
params
# Out:
#    criterion  max_depth  min_samples_leaf
# 0       gini        NaN                 1
# 1       gini        NaN                 5
# 2       gini        NaN                10
# 3       gini        NaN                20
# 4       gini       18.0                 1
# 5       gini       18.0                 5
# 6       gini       18.0                10
# 7       gini       18.0                20
# 8       gini       12.0                 1
# 9       gini       12.0                 5
# 10      gini       12.0                10
# 11      gini       12.0                20
# 12      gini       10.0                 1
# 13      gini       10.0                 5
# 14      gini       10.0                10
# 15      gini       10.0                20
# 16      gini        5.0                 1
# 17      gini        5.0                 5
# 18      gini        5.0                10
# 19      gini        5.0                20
# 20   entropy        NaN                 1
# 21   entropy        NaN                 5
# 22   entropy        NaN                10
# 23   entropy        NaN                20
# 24   entropy       18.0                 1
# 25   entropy       18.0                 5
# 26   entropy       18.0                10
# 27   entropy       18.0                20
# 28   entropy       12.0                 1
# 29   entropy       12.0                 5
# 30   entropy       12.0                10
# 31   entropy       12.0                20
# 32   entropy       10.0                 1
# 33   entropy       10.0                 5
# 34   entropy       10.0                10
# 35   entropy       10.0                20
# 36   entropy        5.0                 1
# 37   entropy        5.0                 5
# 38   entropy        5.0                10
# 39   entropy        5.0                20

# %%
results_df_init.sort_values(by='rank_test_score').head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 11       0.008705      0.000277         0.000500        0.000006
# 21       0.013475      0.000663         0.000559        0.000008
# 6        0.010764      0.000501         0.000533        0.000007
# 25       0.012814      0.000385         0.000533        0.000008
# 10       0.009317      0.000111         0.000509        0.000009
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 11            gini              12                     20
# 21         entropy            None                      5
# 6             gini              18                     10
# 25         entropy              18                      5
# 10            gini              12                     10
#
#                                                params  split0_test_score  \
# 11  {'criterion': 'gini', 'max_depth': 12, 'min_sa...           0.511197
# 21  {'criterion': 'entropy', 'max_depth': None, 'm...           0.498069
# 6   {'criterion': 'gini', 'max_depth': 18, 'min_sa...           0.505019
# 25  {'criterion': 'entropy', 'max_depth': 18, 'min...           0.514286
# 10  {'criterion': 'gini', 'max_depth': 12, 'min_sa...           0.513514
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 11           0.507728           0.508501           0.500773
# 21           0.505410           0.506955           0.506182
# 6            0.496909           0.516229           0.518547
# 25           0.507728           0.506182           0.497682
# 10           0.508501           0.497682           0.515456
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 11           0.530139         0.511668        0.009856                1
# 21           0.533230         0.509969        0.012057                2
# 6            0.512365         0.509814        0.007918                3
# 25           0.523184         0.509812        0.008526                4
# 10           0.513138         0.509658        0.006409                5

# %% [markdown]
# ## RFC grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'max_depth': [None,18, 12, 10, 5],
    'n_estimators': [55, 101, 201],
    'criterion': ['gini', 'entropy'],
}
gr_search = GridSearchCV(RandomForestClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 18, 12, 10, 5],
#                          'n_estimators': [55, 101, 201]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 18, 12, 10, 5],
#                          'n_estimators': [55, 101, 201]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (30, 16)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head(11)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 24       0.133017      0.000760         0.005662        0.000071
# 4        0.326414      0.002122         0.015652        0.000119
# 27       0.085537      0.000592         0.003791        0.000027
# 5        0.650123      0.006646         0.030571        0.000241
# 25       0.244543      0.001940         0.009956        0.000048
# 21       0.152102      0.000850         0.006511        0.000052
# 8        0.526252      0.006801         0.023345        0.000225
# 22       0.278650      0.001058         0.011557        0.000098
# 7        0.266115      0.001449         0.011969        0.000040
# 26       0.483150      0.003499         0.019131        0.000188
# 28       0.154522      0.003316         0.006557        0.000171
#
#    param_criterion param_max_depth param_n_estimators  \
# 24         entropy              10                 55
# 4             gini              18                101
# 27         entropy               5                 55
# 5             gini              18                201
# 25         entropy              10                101
# 21         entropy              12                 55
# 8             gini              12                201
# 22         entropy              12                101
# 7             gini              12                101
# 26         entropy              10                201
# 28         entropy               5                101
#
#                                                params  split0_test_score  \
# 24  {'criterion': 'entropy', 'max_depth': 10, 'n_e...           0.535907
# 4   {'criterion': 'gini', 'max_depth': 18, 'n_esti...           0.514286
# 27  {'criterion': 'entropy', 'max_depth': 5, 'n_es...           0.518919
# 5   {'criterion': 'gini', 'max_depth': 18, 'n_esti...           0.510425
# 25  {'criterion': 'entropy', 'max_depth': 10, 'n_e...           0.511197
# 21  {'criterion': 'entropy', 'max_depth': 12, 'n_e...           0.512741
# 8   {'criterion': 'gini', 'max_depth': 12, 'n_esti...           0.513514
# 22  {'criterion': 'entropy', 'max_depth': 12, 'n_e...           0.510425
# 7   {'criterion': 'gini', 'max_depth': 12, 'n_esti...           0.515058
# 26  {'criterion': 'entropy', 'max_depth': 10, 'n_e...           0.515058
# 28  {'criterion': 'entropy', 'max_depth': 5, 'n_es...           0.500386
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 24           0.530912           0.477589           0.552550
# 4            0.539413           0.479907           0.551005
# 27           0.512365           0.505410           0.545595
# 5            0.530912           0.484544           0.551005
# 25           0.509274           0.498454           0.547913
# 21           0.521638           0.482998           0.544049
# 8            0.527048           0.476043           0.541731
# 22           0.523184           0.493045           0.536321
# 7            0.514683           0.486862           0.550232
# 26           0.523957           0.482998           0.536321
# 28           0.518547           0.506182           0.527821
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 24           0.534003         0.526192        0.025435                1
# 4            0.522411         0.521404        0.024389                2
# 27           0.519320         0.520322        0.013619                3
# 5            0.520866         0.519550        0.022040                4
# 25           0.527048         0.518777        0.017194                5
# 21           0.530912         0.518468        0.020544                6
# 8            0.534003         0.518468        0.023154                7
# 22           0.528594         0.518314        0.015195                8
# 7            0.524730         0.518313        0.020361                9
# 26           0.531685         0.518004        0.018932               10
# 28           0.536321         0.517852        0.013283               11

# %% [markdown]
# ## RFC grid_search CROSS_VALIDATION PLAYTIME

# %%
param_grid = {
    'max_depth': [5,8,10, 12,15],
    'n_estimators': [31, 55, 101,201,501],
    'criterion': ['gini', 'entropy'],
    'oob_score':['False','True']
}
gr_search = GridSearchCV(RandomForestClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 8, 10, 12, 15],
#                          'n_estimators': [31, 55, 101, 201, 501],
#                          'oob_score': ['False', 'True']})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 8, 10, 12, 15],
#                          'n_estimators': [31, 55, 101, 201, 501],
#                          'oob_score': ['False', 'True']})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (100, 17)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head(11)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 64       0.237945      0.000905         0.008432        0.000094
# 21       0.080500      0.000524         0.003496        0.000051
# 69       1.199625      0.029358         0.040093        0.000274
# 5        0.170038      0.000947         0.006598        0.000070
# 19       1.105652      0.007267         0.041551        0.000442
# 35       0.294543      0.003836         0.011981        0.000180
# 82       0.174119      0.001723         0.006596        0.000238
# 4        0.172244      0.001118         0.006705        0.000059
# 32       0.159588      0.001082         0.006680        0.000141
# 28       1.277852      0.006054         0.049111        0.000489
# 49       1.683070      0.016995         0.068616        0.000498
#
#    param_criterion param_max_depth param_n_estimators param_oob_score  \
# 64         entropy               8                101           False
# 21            gini              10                 31            True
# 69         entropy               8                501            True
# 5             gini               5                101            True
# 19            gini               8                501            True
# 35            gini              12                101            True
# 82         entropy              12                 55           False
# 4             gini               5                101           False
# 32            gini              12                 55           False
# 28            gini              10                501           False
# 49            gini              15                501            True
#
#                                                params  split0_test_score  \
# 64  {'criterion': 'entropy', 'max_depth': 8, 'n_es...           0.525869
# 21  {'criterion': 'gini', 'max_depth': 10, 'n_esti...           0.520463
# 69  {'criterion': 'entropy', 'max_depth': 8, 'n_es...           0.505019
# 5   {'criterion': 'gini', 'max_depth': 5, 'n_estim...           0.511197
# 19  {'criterion': 'gini', 'max_depth': 8, 'n_estim...           0.503475
# 35  {'criterion': 'gini', 'max_depth': 12, 'n_esti...           0.504247
# 82  {'criterion': 'entropy', 'max_depth': 12, 'n_e...           0.509653
# 4   {'criterion': 'gini', 'max_depth': 5, 'n_estim...           0.505019
# 32  {'criterion': 'gini', 'max_depth': 12, 'n_esti...           0.528185
# 28  {'criterion': 'gini', 'max_depth': 10, 'n_esti...           0.514286
# 49  {'criterion': 'gini', 'max_depth': 15, 'n_esti...           0.510425
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 64           0.523184           0.486090           0.545595
# 21           0.520866           0.495363           0.547141
# 69           0.516229           0.488408           0.556414
# 5            0.518547           0.497682           0.540958
# 19           0.513910           0.484544           0.551777
# 35           0.509274           0.497682           0.549459
# 82           0.510819           0.494590           0.556414
# 4            0.527821           0.506182           0.537094
# 32           0.513910           0.482998           0.543277
# 28           0.518547           0.479907           0.547913
# 49           0.521638           0.469861           0.548686
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 64           0.540958         0.524339        0.020951                1
# 21           0.531685         0.523103        0.016929                2
# 69           0.540958         0.521406        0.024462                3
# 5            0.535549         0.520787        0.015847                4
# 19           0.548686         0.520479        0.026072                5
# 35           0.539413         0.520015        0.020523                6
# 82           0.527048         0.519705        0.021034                7
# 4            0.519320         0.519087        0.012370                8
# 32           0.527048         0.519084        0.020300                9
# 28           0.534003         0.518931        0.022855               10
# 49           0.539413         0.518005        0.027525               11

# %% [markdown]
# ## NBC grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'var_smoothing': [.000000001,.000000002,.000000003]
}
gr_search = GridSearchCV(GaussianNB(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=GaussianNB(),
#              param_grid={'var_smoothing': [1e-09, 2e-09, 3e-09]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=GaussianNB(),
#              param_grid={'var_smoothing': [1e-09, 2e-09, 3e-09]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (3, 14)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.004008      0.002160         0.001453        0.000356
# 1       0.002031      0.000123         0.000955        0.000105
# 2       0.001655      0.000086         0.000743        0.000046
#
#   param_var_smoothing                    params  split0_test_score  \
# 0                 0.0  {'var_smoothing': 1e-09}           0.517375
# 1                 0.0  {'var_smoothing': 2e-09}           0.517375
# 2                 0.0  {'var_smoothing': 3e-09}           0.517375
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.497682           0.503864           0.527821           0.525502
# 1           0.497682           0.503864           0.527821           0.525502
# 2           0.497682           0.503864           0.527821           0.525502
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.514449        0.011855                1
# 1         0.514449        0.011855                1
# 2         0.514449        0.011855                1

# %% [markdown]
# ## GBC grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'learning_rate': [0.1,0.2,0.5,1.0, 5.0],
    'n_estimators': [55, 101, 201],
    'min_samples_leaf': [1,5,10,20],
}
gr_search = GridSearchCV(GradientBoostingClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.1, 0.2, 0.5, 1.0, 5.0],
#                          'min_samples_leaf': [1, 5, 10, 20],
#                          'n_estimators': [55, 101, 201]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.1, 0.2, 0.5, 1.0, 5.0],
#                          'min_samples_leaf': [1, 5, 10, 20],
#                          'n_estimators': [55, 101, 201]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (60, 16)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 12       0.161948      0.000715         0.001126        0.000015
# 4        0.292017      0.004093         0.001675        0.000055
# 0        0.164831      0.013543         0.001132        0.000071
# 22       0.297993      0.001284         0.001840        0.000054
# 9        0.163661      0.003110         0.001321        0.000114
#
#    param_learning_rate param_min_samples_leaf param_n_estimators  \
# 12                 0.2                      1                 55
# 4                  0.1                      5                101
# 0                  0.1                      1                 55
# 22                 0.2                     20                101
# 9                  0.1                     20                 55
#
#                                                params  split0_test_score  \
# 12  {'learning_rate': 0.2, 'min_samples_leaf': 1, ...           0.525869
# 4   {'learning_rate': 0.1, 'min_samples_leaf': 5, ...           0.530502
# 0   {'learning_rate': 0.1, 'min_samples_leaf': 1, ...           0.538996
# 22  {'learning_rate': 0.2, 'min_samples_leaf': 20,...           0.508108
# 9   {'learning_rate': 0.1, 'min_samples_leaf': 20,...           0.521236
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 12           0.533230           0.496136           0.531685
# 4            0.515456           0.489181           0.543277
# 0            0.527821           0.483771           0.528594
# 22           0.512365           0.482226           0.563369
# 9            0.527048           0.488408           0.520093
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 12           0.530139         0.523412        0.013857                1
# 4            0.534003         0.522484        0.018909                2
# 0            0.529366         0.521710        0.019398                3
# 22           0.522411         0.517696        0.026408                4
# 9            0.522411         0.515839        0.013918                5

# %% [markdown]
# ## GBC grid_search CROSS_VALIDATION PLAYTIME

# %%
param_grid = {
    'learning_rate': [0.02,0.05,0.1],
    'n_estimators': [21,31,55, 101],
    'min_samples_leaf': [2,5,10],
}
gr_search = GridSearchCV(GradientBoostingClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.02, 0.05, 0.1],
#                          'min_samples_leaf': [2, 5, 10],
#                          'n_estimators': [21, 31, 55, 101]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.02, 0.05, 0.1],
#                          'min_samples_leaf': [2, 5, 10],
#                          'n_estimators': [21, 31, 55, 101]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (36, 16)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 31       0.296887      0.001743         0.001704        0.000051
# 1        0.089248      0.000589         0.000878        0.000061
# 5        0.088754      0.000313         0.000820        0.000030
# 9        0.090672      0.002445         0.000891        0.000083
# 4        0.060525      0.000337         0.000718        0.000036
#
#    param_learning_rate param_min_samples_leaf param_n_estimators  \
# 31                 0.1                      5                101
# 1                 0.02                      2                 31
# 5                 0.02                      5                 31
# 9                 0.02                     10                 31
# 4                 0.02                      5                 21
#
#                                                params  split0_test_score  \
# 31  {'learning_rate': 0.1, 'min_samples_leaf': 5, ...           0.530502
# 1   {'learning_rate': 0.02, 'min_samples_leaf': 2,...           0.527413
# 5   {'learning_rate': 0.02, 'min_samples_leaf': 5,...           0.523552
# 9   {'learning_rate': 0.02, 'min_samples_leaf': 10...           0.523552
# 4   {'learning_rate': 0.02, 'min_samples_leaf': 5,...           0.528958
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 31           0.515456           0.489181           0.543277
# 1            0.525502           0.501546           0.524730
# 5            0.525502           0.501546           0.523957
# 9            0.525502           0.501546           0.523957
# 4            0.525502           0.505410           0.522411
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 31           0.534003         0.522484        0.018909                1
# 1            0.530139         0.521866        0.010330                2
# 5            0.527821         0.520475        0.009583                3
# 9            0.526275         0.520166        0.009363                4
# 4            0.510819         0.518620        0.008989                5

# %% [markdown]
# ## CATboost grid_search CROSS_VALIDATION k=5

# %%
# Create and fit the thing
CATb = CatBoostClassifier(verbose=False,depth=10,learning_rate=1.0)
CATb.fit(X_train,y_train)
CATb_preds = CATb.predict(X_train)
pd.crosstab(CATb_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         3178    17
# 1           10  3266

# %%
print(f'Accuracy-Train {round(CATb.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(CATb.score(X_validate,y_validate),4)}')
print(classification_report(y_train,CATb_preds))
print(classification_report(y_validate,CATb.predict(X_validate)))
# Out:
# Accuracy-Train 0.9958
# Accuracy-Validate 0.5
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3188
#            1       1.00      0.99      1.00      3283
#
#     accuracy                           1.00      6471
#    macro avg       1.00      1.00      1.00      6471
# weighted avg       1.00      1.00      1.00      6471
#
#               precision    recall  f1-score   support
#
#            0       0.49      0.48      0.49      1179
#            1       0.51      0.52      0.51      1215
#
#     accuracy                           0.50      2394
#    macro avg       0.50      0.50      0.50      2394
# weighted avg       0.50      0.50      0.50      2394

# %%
param_grid = {
    'verbose': [False],
    'depth': [5, 10, 12],
    'learning_rate': [0.1,0.2, 0.5],
}
gr_search = GridSearchCV(CatBoostClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=<catboost.core.CatBoostClassifier object at 0x11fc739a0>,
#              param_grid={'depth': [5, 10, 12], 'learning_rate': [0.1, 0.2, 0.5],
#                          'verbose': [False]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=<catboost.core.CatBoostClassifier object at 0x11fc739a0>,
#              param_grid={'depth': [5, 10, 12], 'learning_rate': [0.1, 0.2, 0.5],
#                          'verbose': [False]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (9, 16)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_depth  \
# 6       7.078878      0.028331         0.002407        0.000089          12
# 8       6.519551      0.063714         0.002210        0.000011          12
# 5       2.700013      0.031329         0.001873        0.000227          10
# 3       2.835837      0.026854         0.001684        0.000026          10
# 7       6.969984      0.034486         0.002280        0.000033          12
#
#   param_learning_rate param_verbose  \
# 6                 0.1         False
# 8                 0.5         False
# 5                 0.5         False
# 3                 0.1         False
# 7                 0.2         False
#
#                                               params  split0_test_score  \
# 6  {'depth': 12, 'learning_rate': 0.1, 'verbose':...           0.512741
# 8  {'depth': 12, 'learning_rate': 0.5, 'verbose':...           0.498842
# 5  {'depth': 10, 'learning_rate': 0.5, 'verbose':...           0.515058
# 3  {'depth': 10, 'learning_rate': 0.1, 'verbose':...           0.491892
# 7  {'depth': 12, 'learning_rate': 0.2, 'verbose':...           0.501158
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 6           0.545595           0.494590           0.533230           0.511592
# 8           0.535549           0.491499           0.513910           0.509274
# 5           0.521638           0.482226           0.527048           0.501546
# 3           0.529366           0.477589           0.535549           0.509274
# 7           0.528594           0.475270           0.527821           0.510046
#
#    mean_test_score  std_test_score  rank_test_score
# 6         0.519550        0.017878                1
# 8         0.509815        0.015068                2
# 5         0.509503        0.016083                3
# 3         0.508734        0.021903                4
# 7         0.508578        0.019685                5

# %% [markdown]
# ## SCALE for Logistic regression, MLP, etc.

# %%
sc_X = StandardScaler()
X_train_scaled = sc_X.fit_transform(X_train)
X_validate_scaled = sc_X.transform(X_validate)
X_test_scaled = sc_X.transform(X_test)

# %%
mlp = MLPClassifier(hidden_layer_sizes=(1024,512,128),activation="relu",random_state=2013,
                    batch_size=200,solver='adam')
mlp.fit(X_train_scaled, y_train)
mlp_preds = mlp.predict(X_train_scaled)
print(mlp.score(X_train_scaled, y_train))
pd.crosstab(mlp_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# 0.9528666357595426
# is_under     0     1
# row_0
# 0         3011   128
# 1          177  3155

# %%
mlp.n_layers_
# Out:
# 5

# %%
print(f'Accuracy-Train {round(mlp.score(X_train_scaled,y_train),4)}')
print(f'Accuracy-Validate {round(mlp.score(X_validate_scaled,y_validate),4)}')
print(classification_report(y_train,mlp_preds))
print(classification_report(y_validate,mlp.predict(X_validate_scaled)))
# Out:
# Accuracy-Train 0.9529
# Accuracy-Validate 0.5046
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      3188
#            1       0.95      0.96      0.95      3283
#
#     accuracy                           0.95      6471
#    macro avg       0.95      0.95      0.95      6471
# weighted avg       0.95      0.95      0.95      6471
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.50      1179
#            1       0.51      0.50      0.51      1215
#
#     accuracy                           0.50      2394
#    macro avg       0.50      0.50      0.50      2394
# weighted avg       0.50      0.50      0.50      2394

# %% [markdown]
# ## KNN grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'n_neighbors': [70],
    'weights': ['uniform','distance'],
    'algorithm':['ball_tree','brute'],
    'leaf_size': [3,4,5,6,7,8,9],
}
gr_search = GridSearchCV(KNeighborsClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['ball_tree', 'brute'],
#                          'leaf_size': [3, 4, 5, 6, 7, 8, 9],
#                          'n_neighbors': [70],
#                          'weights': ['uniform', 'distance']})

# %%
gr_search.fit(X_train, y_train)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['ball_tree', 'brute'],
#                          'leaf_size': [3, 4, 5, 6, 7, 8, 9],
#                          'n_neighbors': [70],
#                          'weights': ['uniform', 'distance']})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (28, 17)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head(31)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 13       0.002132      0.000051         0.043323        0.000648
# 7        0.002101      0.000023         0.043425        0.000718
# 11       0.002086      0.000024         0.043292        0.000646
# 9        0.002112      0.000041         0.043653        0.000564
# 25       0.000814      0.000022         0.026051        0.001828
# 23       0.000824      0.000033         0.025263        0.001209
# 21       0.000832      0.000056         0.024931        0.001153
# 19       0.000811      0.000017         0.024731        0.000951
# 17       0.000817      0.000026         0.024566        0.000843
# 15       0.000829      0.000018         0.024888        0.000706
# 27       0.001042      0.000443         0.025220        0.001008
# 1        0.002287      0.000062         0.046821        0.000654
# 3        0.002268      0.000013         0.046744        0.000587
# 5        0.002272      0.000029         0.046803        0.000631
# 4        0.002350      0.000116         0.053081        0.000504
# 2        0.002261      0.000020         0.052621        0.000521
# 0        0.004014      0.003322         0.059570        0.013830
# 6        0.002099      0.000027         0.049328        0.001055
# 10       0.002152      0.000078         0.049380        0.000853
# 12       0.002305      0.000194         0.051065        0.001173
# 8        0.002089      0.000021         0.049181        0.000625
# 18       0.000852      0.000015         0.031520        0.000733
# 20       0.000852      0.000027         0.031860        0.001360
# 14       0.000859      0.000065         0.035388        0.009368
# 22       0.000834      0.000025         0.032190        0.001780
# 26       0.000828      0.000037         0.030897        0.001103
# 24       0.000835      0.000019         0.032199        0.000906
# 16       0.000846      0.000036         0.031146        0.001022
#
#    param_algorithm param_leaf_size param_n_neighbors param_weights  \
# 13       ball_tree               9                70      distance
# 7        ball_tree               6                70      distance
# 11       ball_tree               8                70      distance
# 9        ball_tree               7                70      distance
# 25           brute               8                70      distance
# 23           brute               7                70      distance
# 21           brute               6                70      distance
# 19           brute               5                70      distance
# 17           brute               4                70      distance
# 15           brute               3                70      distance
# 27           brute               9                70      distance
# 1        ball_tree               3                70      distance
# 3        ball_tree               4                70      distance
# 5        ball_tree               5                70      distance
# 4        ball_tree               5                70       uniform
# 2        ball_tree               4                70       uniform
# 0        ball_tree               3                70       uniform
# 6        ball_tree               6                70       uniform
# 10       ball_tree               8                70       uniform
# 12       ball_tree               9                70       uniform
# 8        ball_tree               7                70       uniform
# 18           brute               5                70       uniform
# 20           brute               6                70       uniform
# 14           brute               3                70       uniform
# 22           brute               7                70       uniform
# 26           brute               9                70       uniform
# 24           brute               8                70       uniform
# 16           brute               4                70       uniform
#
#                                                params  split0_test_score  \
# 13  {'algorithm': 'ball_tree', 'leaf_size': 9, 'n_...           0.528958
# 7   {'algorithm': 'ball_tree', 'leaf_size': 6, 'n_...           0.528958
# 11  {'algorithm': 'ball_tree', 'leaf_size': 8, 'n_...           0.528958
# 9   {'algorithm': 'ball_tree', 'leaf_size': 7, 'n_...           0.528958
# 25  {'algorithm': 'brute', 'leaf_size': 8, 'n_neig...           0.528185
# 23  {'algorithm': 'brute', 'leaf_size': 7, 'n_neig...           0.528185
# 21  {'algorithm': 'brute', 'leaf_size': 6, 'n_neig...           0.528185
# 19  {'algorithm': 'brute', 'leaf_size': 5, 'n_neig...           0.528185
# 17  {'algorithm': 'brute', 'leaf_size': 4, 'n_neig...           0.528185
# 15  {'algorithm': 'brute', 'leaf_size': 3, 'n_neig...           0.528185
# 27  {'algorithm': 'brute', 'leaf_size': 9, 'n_neig...           0.528185
# 1   {'algorithm': 'ball_tree', 'leaf_size': 3, 'n_...           0.525097
# 3   {'algorithm': 'ball_tree', 'leaf_size': 4, 'n_...           0.525097
# 5   {'algorithm': 'ball_tree', 'leaf_size': 5, 'n_...           0.525097
# 4   {'algorithm': 'ball_tree', 'leaf_size': 5, 'n_...           0.508108
# 2   {'algorithm': 'ball_tree', 'leaf_size': 4, 'n_...           0.508108
# 0   {'algorithm': 'ball_tree', 'leaf_size': 3, 'n_...           0.508108
# 6   {'algorithm': 'ball_tree', 'leaf_size': 6, 'n_...           0.511969
# 10  {'algorithm': 'ball_tree', 'leaf_size': 8, 'n_...           0.511969
# 12  {'algorithm': 'ball_tree', 'leaf_size': 9, 'n_...           0.511969
# 8   {'algorithm': 'ball_tree', 'leaf_size': 7, 'n_...           0.511969
# 18  {'algorithm': 'brute', 'leaf_size': 5, 'n_neig...           0.510425
# 20  {'algorithm': 'brute', 'leaf_size': 6, 'n_neig...           0.510425
# 14  {'algorithm': 'brute', 'leaf_size': 3, 'n_neig...           0.510425
# 22  {'algorithm': 'brute', 'leaf_size': 7, 'n_neig...           0.510425
# 26  {'algorithm': 'brute', 'leaf_size': 9, 'n_neig...           0.510425
# 24  {'algorithm': 'brute', 'leaf_size': 8, 'n_neig...           0.510425
# 16  {'algorithm': 'brute', 'leaf_size': 4, 'n_neig...           0.510425
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 13           0.519320           0.467543           0.527048
# 7            0.519320           0.467543           0.527048
# 11           0.519320           0.467543           0.527048
# 9            0.519320           0.467543           0.527048
# 25           0.518547           0.470634           0.524730
# 23           0.518547           0.470634           0.524730
# 21           0.518547           0.470634           0.524730
# 19           0.518547           0.470634           0.524730
# 17           0.518547           0.470634           0.524730
# 15           0.518547           0.470634           0.524730
# 27           0.518547           0.470634           0.524730
# 1            0.518547           0.467543           0.524730
# 3            0.518547           0.467543           0.524730
# 5            0.518547           0.467543           0.524730
# 4            0.505410           0.485317           0.510046
# 2            0.505410           0.485317           0.510046
# 0            0.505410           0.485317           0.510046
# 6            0.505410           0.481453           0.508501
# 10           0.505410           0.481453           0.508501
# 12           0.505410           0.481453           0.508501
# 8            0.505410           0.481453           0.508501
# 18           0.500773           0.483771           0.505410
# 20           0.500773           0.483771           0.505410
# 14           0.500773           0.483771           0.505410
# 22           0.500773           0.483771           0.505410
# 26           0.500773           0.483771           0.505410
# 24           0.500773           0.483771           0.505410
# 16           0.500773           0.483771           0.505410
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 13           0.527821         0.514138        0.023544                1
# 7            0.527821         0.514138        0.023544                1
# 11           0.527821         0.514138        0.023544                1
# 9            0.527821         0.514138        0.023544                1
# 25           0.527821         0.513983        0.021948                5
# 23           0.527821         0.513983        0.021948                5
# 21           0.527821         0.513983        0.021948                5
# 19           0.527821         0.513983        0.021948                5
# 17           0.527821         0.513983        0.021948                5
# 15           0.527821         0.513983        0.021948                5
# 27           0.527821         0.513983        0.021948                5
# 1            0.526275         0.512438        0.022608               12
# 3            0.526275         0.512438        0.022608               12
# 5            0.526275         0.512438        0.022608               12
# 4            0.518547         0.505486        0.011001               15
# 2            0.518547         0.505486        0.011001               15
# 0            0.518547         0.505486        0.011001               15
# 6            0.516229         0.504712        0.012175               18
# 10           0.516229         0.504712        0.012175               18
# 12           0.516229         0.504712        0.012175               18
# 8            0.516229         0.504712        0.012175               18
# 18           0.520866         0.504249        0.012223               22
# 20           0.520866         0.504249        0.012223               22
# 14           0.520866         0.504249        0.012223               22
# 22           0.520866         0.504249        0.012223               22
# 26           0.520866         0.504249        0.012223               22
# 24           0.520866         0.504249        0.012223               22
# 16           0.520866         0.504249        0.012223               22

# %% [markdown]
# ## LOG grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'penalty': ['none','l1','l2','elasticnet'],
    'class_weight': ['balanced',None],
    'max_iter':[100,50,200]
}
gr_search = GridSearchCV(LogisticRegression(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'class_weight': ['balanced', None],
#                          'max_iter': [100, 50, 200],
#                          'penalty': ['none', 'l1', 'l2', 'elasticnet']})

# %%
gr_search.fit(X_train, y_train)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1091, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 61, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1091, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 61, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.50239323        nan 0.50053803        nan 0.50502014        nan
#  0.50548501        nan 0.50332082        nan 0.50517446        nan
#  0.50826589        nan 0.50857405        nan 0.50517625        nan
#  0.5045573         nan 0.51073789        nan 0.51027409        nan]
#   warnings.warn(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'class_weight': ['balanced', None],
#                          'max_iter': [100, 50, 200],
#                          'penalty': ['none', 'l1', 'l2', 'elasticnet']})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (24, 16)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head(11)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 20       0.067161      0.010093         0.001061        0.000409
# 22       0.081435      0.016794         0.001249        0.000339
# 14       0.037878      0.006469         0.000835        0.000591
# 12       0.037593      0.010323         0.000949        0.000445
# 6        0.018426      0.003536         0.000762        0.000377
# 16       0.018579      0.004576         0.000705        0.000391
# 10       0.073666      0.035551         0.000729        0.000388
# 4        0.023744      0.008862         0.000923        0.000448
# 18       0.019453      0.003739         0.000781        0.000357
# 8        0.068718      0.007945         0.001915        0.001656
# 0        0.042018      0.016493         0.000831        0.000481
#
#    param_class_weight param_max_iter param_penalty  \
# 20               None            200          none
# 22               None            200            l2
# 14               None            100            l2
# 12               None            100          none
# 6            balanced             50            l2
# 16               None             50          none
# 10           balanced            200            l2
# 4            balanced             50          none
# 18               None             50            l2
# 8            balanced            200          none
# 0            balanced            100          none
#
#                                                params  split0_test_score  \
# 20  {'class_weight': None, 'max_iter': 200, 'penal...           0.525869
# 22  {'class_weight': None, 'max_iter': 200, 'penal...           0.526641
# 14  {'class_weight': None, 'max_iter': 100, 'penal...           0.525869
# 12  {'class_weight': None, 'max_iter': 100, 'penal...           0.519691
# 6   {'class_weight': 'balanced', 'max_iter': 50, '...           0.511969
# 16  {'class_weight': None, 'max_iter': 50, 'penalt...           0.509653
# 10  {'class_weight': 'balanced', 'max_iter': 200, ...           0.521236
# 4   {'class_weight': 'balanced', 'max_iter': 50, '...           0.519691
# 18  {'class_weight': None, 'max_iter': 50, 'penalt...           0.514286
# 8   {'class_weight': 'balanced', 'max_iter': 200, ...           0.514286
# 0   {'class_weight': 'balanced', 'max_iter': 100, ...           0.515830
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 20           0.507728           0.497682           0.519320
# 22           0.509274           0.493818           0.517002
# 14           0.509274           0.493818           0.518547
# 12           0.511592           0.492272           0.515456
# 6            0.500773           0.492272           0.525502
# 16           0.511592           0.493818           0.517774
# 10           0.514683           0.484544           0.512365
# 4            0.508501           0.482226           0.517774
# 18           0.510046           0.484544           0.515456
# 8            0.511592           0.489181           0.508501
# 0            0.506182           0.480680           0.521638
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 20           0.503091         0.510738        0.010398                1
# 22           0.504637         0.510274        0.011106                2
# 14           0.495363         0.508574        0.012580                3
# 12           0.502318         0.508266        0.009843                4
# 6            0.496909         0.505485        0.011942                5
# 16           0.493045         0.505176        0.009961                6
# 10           0.493045         0.505174        0.013949                7
# 4            0.496909         0.505020        0.013967                8
# 18           0.498454         0.504557        0.011673                9
# 8            0.493045         0.503321        0.010208               10
# 0            0.487635         0.502393        0.015840               11

# %% [markdown]
# ## SVM grid_search CROSS_VALIDATION k=5

# %%
param_grid = {
    'shrinking': [True,False],
    'C':[1,5,10]
}
gr_search = GridSearchCV(SVC(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 5, 10], 'shrinking': [True, False]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 5, 10], 'shrinking': [True, False]})

# %%
results = gr_search.cv_results_
results_df_init = pd.DataFrame(results)
results_df_init.shape
# Out:
# (6, 15)

# %%
params = pd.DataFrame(results['params'])
results_df_init.sort_values(by='rank_test_score').head(11)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 4       0.404305      0.005469         0.222049        0.005807      10
# 5       0.415540      0.009967         0.219741        0.001375      10
# 2       0.397930      0.002617         0.219404        0.000763       5
# 3       0.398342      0.001694         0.219931        0.001258       5
# 0       0.404234      0.012649         0.223019        0.000948       1
# 1       0.394556      0.000830         0.222639        0.001194       1
#
#   param_shrinking                         params  split0_test_score  \
# 4            True   {'C': 10, 'shrinking': True}           0.527413
# 5           False  {'C': 10, 'shrinking': False}           0.527413
# 2            True    {'C': 5, 'shrinking': True}           0.525869
# 3           False   {'C': 5, 'shrinking': False}           0.525869
# 0            True    {'C': 1, 'shrinking': True}           0.522780
# 1           False   {'C': 1, 'shrinking': False}           0.522780
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 4           0.507728           0.509274           0.534003           0.527048
# 5           0.507728           0.509274           0.534003           0.527048
# 2           0.508501           0.505410           0.525502           0.531685
# 3           0.508501           0.504637           0.525502           0.531685
# 0           0.514683           0.502318           0.513138           0.528594
# 1           0.514683           0.502318           0.513138           0.527821
#
#    mean_test_score  std_test_score  rank_test_score
# 4         0.521093        0.010587                1
# 5         0.521093        0.010587                1
# 2         0.519393        0.010436                3
# 3         0.519239        0.010645                4
# 0         0.516303        0.008958                5
# 1         0.516148        0.008749                6

# %% [markdown]
# # NOW return to single iterations of each model with optimized hyperparameters.

# %% [markdown]
# ### RFC: entropy, max_d=5,n_est=55

# %%
# create the Random Forest model 
rf1 = RandomForestClassifier(criterion='entropy',n_estimators=55,max_depth=5)
# fit the model to the TRAIN dataset1
rf1.fit(X_train, y_train)
# use the model by calling for the predictions made via the TRAIN dataset
rf1_preds = rf1.predict(X_train)
pd.crosstab(rf1_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         1449   919
# 1         1739  2364

# %%
print(f'Accuracy-Train {round(rf1.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(rf1.score(X_validate,y_validate),4)}')
print(classification_report(y_train,rf1_preds))
print(classification_report(y_validate,rf1.predict(X_validate)))
# Out:
# Accuracy-Train 0.5892
# Accuracy-Validate 0.5054
#               precision    recall  f1-score   support
#
#            0       0.61      0.45      0.52      3188
#            1       0.58      0.72      0.64      3283
#
#     accuracy                           0.59      6471
#    macro avg       0.59      0.59      0.58      6471
# weighted avg       0.59      0.59      0.58      6471
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.37      0.43      1179
#            1       0.51      0.63      0.57      1215
#
#     accuracy                           0.51      2394
#    macro avg       0.50      0.50      0.50      2394
# weighted avg       0.50      0.51      0.50      2394

# %% [markdown]
# ### KNN: n_neighbors=70, "distance" based weighting ,"brute" computation

# %%
knn = KNeighborsClassifier(n_neighbors=70,weights='distance',algorithm='brute')
knn.fit(X_train_scaled, y_train)
knn_preds = knn.predict(X_train_scaled)
print(knn.score(X_train_scaled, y_train))
pd.crosstab(knn_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# 0.9958275382475661
# is_under     0     1
# row_0
# 0         3184    23
# 1            4  3260

# %%
print(f'Accuracy-Train {round(knn.score(X_train_scaled,y_train),4)}')
print(f'Accuracy-Validate {round(knn.score(X_validate_scaled,y_validate),4)}')
print(classification_report(y_train,knn_preds))
print(classification_report(y_validate,knn.predict(X_validate_scaled)))
# Out:
# Accuracy-Train 0.9958
# Accuracy-Validate 0.5058
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3188
#            1       1.00      0.99      1.00      3283
#
#     accuracy                           1.00      6471
#    macro avg       1.00      1.00      1.00      6471
# weighted avg       1.00      1.00      1.00      6471
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.48      0.49      1179
#            1       0.51      0.53      0.52      1215
#
#     accuracy                           0.51      2394
#    macro avg       0.51      0.51      0.51      2394
# weighted avg       0.51      0.51      0.51      2394

# %% [markdown]
# ### GBC: learning_rate=0.05, n_est=31,min_samples_leaf=2

# %%
# create the Random Forest model 
gbc = GradientBoostingClassifier(learning_rate=0.05,n_estimators=31,min_samples_leaf=2)
# fit the model to the TRAIN dataset:
gbc.fit(X_train, y_train)
# use the model by calling for the predictions made via the TRAIN dataset
gbc_preds = gbc.predict(X_train)
pd.crosstab(gbc_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         1059   814
# 1         2129  2469

# %%
print(f'Accuracy-Train {round(gbc.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(gbc.score(X_validate,y_validate),4)}')
print(classification_report(y_train,gbc_preds))
print(classification_report(y_validate,gbc.predict(X_validate)))
# Out:
# Accuracy-Train 0.5452
# Accuracy-Validate 0.5205
#               precision    recall  f1-score   support
#
#            0       0.57      0.33      0.42      3188
#            1       0.54      0.75      0.63      3283
#
#     accuracy                           0.55      6471
#    macro avg       0.55      0.54      0.52      6471
# weighted avg       0.55      0.55      0.52      6471
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.32      0.39      1179
#            1       0.52      0.72      0.60      1215
#
#     accuracy                           0.52      2394
#    macro avg       0.52      0.52      0.50      2394
# weighted avg       0.52      0.52      0.50      2394

# %%
cols = X_train.columns

# %%
cols
# Out:
# Index(['week_num', 'temp', 'humidity', 'wind', 'spread', 'ou',
#        'abnormal_start', 'is_playoff', 'playoff_implications', 'is_turf',
#        'is_outdoor'],
#       dtype='object')

# %%
gini = gbc.feature_importances_

# %%
gini
# Out:
# array([0.06697706, 0.10438619, 0.14205592, 0.30226101, 0.16706896,
#        0.20315575, 0.00778298, 0.        , 0.        , 0.00631212,
#        0.        ])

# %%
feat_df = pd.DataFrame({'Feature':cols, 'Coef':gini})

# %%
feat_df.sort_values('Coef',ascending=False)
# Out:
#                  Feature      Coef
# 3                   wind  0.302261
# 5                     ou  0.203156
# 4                 spread  0.167069
# 2               humidity  0.142056
# 1                   temp  0.104386
# 0               week_num  0.066977
# 6         abnormal_start  0.007783
# 9                is_turf  0.006312
# 7             is_playoff  0.000000
# 8   playoff_implications  0.000000
# 10            is_outdoor  0.000000
