# %%
#standard ds imports
import pandas as pd
import numpy as np
#viz and stats
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# .py imports
#import wranglerer as wr
#import modeling as md
import os
#sklearn imports
from sklearn.model_selection import train_test_split,cross_val_score, GridSearchCV
import sklearn.preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix, plot_confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
#CATboost imports
from catboost import CatBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
import explore_r as ex

# %%
df = pd.read_csv('prepped_data.csv')

# %%
df = df.drop(columns=['date', 'day_of_week', 'start_time','home_score',
       'home_wins', 'away_score', 'away_wins','total_scores'])
df['spread'] = abs(df['spread'])

# %%
df.head()
# Out:
#    week_num  temp  humidity  wind  spread    ou  is_under  abnormal_start  \
# 0        19    72         0     0     1.0  51.0         0               0
# 1        19    52        48    14     2.5  45.5         1               0
# 2        19    22        55    13     1.5  48.0         1               0
# 3        19    32        10     0     5.5  49.0         1               0
# 4        19    55        47    19     4.0  47.0         1               0
#
#    is_playoff  playoff_implications  is_turf  is_outdoor
# 0           1                     1        0           0
# 1           1                     1        0           1
# 2           1                     1        0           1
# 3           1                     1        1           1
# 4           1                     1        0           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10811 entries, 0 to 10810
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   week_num              10811 non-null  int64
#  1   temp                  10811 non-null  int64
#  2   humidity              10811 non-null  int64
#  3   wind                  10811 non-null  int64
#  4   spread                10811 non-null  float64
#  5   ou                    10811 non-null  float64
#  6   is_under              10811 non-null  int64
#  7   abnormal_start        10811 non-null  int64
#  8   is_playoff            10811 non-null  int64
#  9   playoff_implications  10811 non-null  int64
#  10  is_turf               10811 non-null  int64
#  11  is_outdoor            10811 non-null  int64
# dtypes: float64(2), int64(10)
# memory usage: 1013.7 KB

# %% [markdown]
# ## ESTABLISH BASELINE 50.7%

# %%
df.is_under.value_counts(normalize=True)
# Out:
# 1    0.507354
# 0    0.492646
# Name: is_under, dtype: float64

# %%
df['baseline'] = 1

# %%
baseline_accuracy = (df.baseline == df.is_under).mean()
print(f'baseline accuracy: {baseline_accuracy:.2%}')
# Out:
# baseline accuracy: 50.74%

# %%
subset = df[df.is_under == 1]
baseline_recall = (subset.baseline == subset.is_under).mean()
print(f'baseline recall: {baseline_recall:.2%}')
# Out:
# baseline recall: 100.00%

# %%
subset = df[df.baseline == 1]
baseline_precision = (subset.baseline == subset.is_under).mean()
print(f'baseline precision: {baseline_precision:.2%}')
# Out:
# baseline precision: 50.74%

# %%
df.drop(columns='baseline',inplace=True)

# %%
X_train, y_train, X_validate, y_validate, X_test, y_test = ex.train_validate_test(df,'is_under')

# %%
X_train.shape, y_train.shape, X_validate.shape, y_validate.shape, X_test.shape, y_test.shape
# Out:
# ((6471, 11), (6471,), (2394, 11), (2394,), (1946, 11), (1946,))

# %%
X_train.head()
# Out:
#       week_num  temp  humidity  wind  spread    ou  abnormal_start  \
# 1713        12    72         0     0     4.0  49.0               0
# 2164        17    72         0     0     7.5  38.0               0
# 2554         9    72         0     0     1.0  42.5               1
# 3117         6    58        52    10    12.5  40.0               0
# 9819        13    51        49    14     5.0  39.5               0
#
#       is_playoff  playoff_implications  is_turf  is_outdoor
# 1713           0                     1        1           0
# 2164           0                     1        0           0
# 2554           0                     0        0           0
# 3117           0                     0        0           1
# 9819           0                     1        0           1

# %% [markdown]
# # MODELING

# %% [markdown]
# ## DTC VANILLA

# %%
# create the Decision Tree Classifier model 
dtc = DecisionTreeClassifier()

# %%
# fit the model to the TRAIN dataset:
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# use the model by calling for the predictions made via the TRAIN dataset
dtc_preds = dtc.predict(X_train)
pd.crosstab(dtc_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         3180    20
# 1            0  3271

# %%
print(f'Accuracy-Train {round(dtc.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(dtc.score(X_validate,y_validate),4)}')
print(classification_report(y_train,dtc_preds))
print(classification_report(y_validate,dtc.predict(X_validate)))
# Out:
# Accuracy-Train 0.9969
# Accuracy-Validate 0.5134
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3180
#            1       1.00      0.99      1.00      3291
#
#     accuracy                           1.00      6471
#    macro avg       1.00      1.00      1.00      6471
# weighted avg       1.00      1.00      1.00      6471
#
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.50      1178
#            1       0.52      0.53      0.52      1216
#
#     accuracy                           0.51      2394
#    macro avg       0.51      0.51      0.51      2394
# weighted avg       0.51      0.51      0.51      2394

# %% [markdown]
# ## DTC maxDepth = X

# %%
# create the Decision Tree Classifier model 
dtc = DecisionTreeClassifier(max_depth=5,min_samples_leaf=5)

# %%
# fit the model to the TRAIN dataset:
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=5)

# %%
# use the model by calling for the predictions made via the TRAIN dataset
dtc_preds = dtc.predict(X_train)
pd.crosstab(dtc_preds,y_train) # a confusion matrix with ACTUALS as columns and PREDICTIONS as rows
# Out:
# is_under     0     1
# row_0
# 0         1604  1365
# 1         1576  1926

# %%
print(f'Accuracy-Train {round(dtc.score(X_train,y_train),4)}')
print(f'Accuracy-Validate {round(dtc.score(X_validate,y_validate),4)}')
print(classification_report(y_train,dtc_preds))
print(classification_report(y_validate,dtc.predict(X_validate)))
# Out:
# Accuracy-Train 0.5455
# Accuracy-Validate 0.5029
#               precision    recall  f1-score   support
#
#            0       0.54      0.50      0.52      3180
#            1       0.55      0.59      0.57      3291
#
#     accuracy                           0.55      6471
#    macro avg       0.55      0.54      0.54      6471
# weighted avg       0.55      0.55      0.54      6471
#
#               precision    recall  f1-score   support
#
#            0       0.49      0.46      0.48      1178
#            1       0.51      0.55      0.53      1216
#
#     accuracy                           0.50      2394
#    macro avg       0.50      0.50      0.50      2394
# weighted avg       0.50      0.50      0.50      2394

# %% [markdown]
# ## CROSS_VALIDATION k=5

# %%
cross_val_score(dtc, X_train, y_train, cv=10)
# Out:
# array([0.49382716, 0.51159196, 0.49304482, 0.46522411, 0.50695518,
#        0.51931994, 0.52086553, 0.50695518, 0.51468315, 0.49149923])

# %%
param_grid = {
    'max_depth': [None,18, 12, 10, 5],
    'min_samples_leaf': [1, 5, 10, 20],
    'criterion': ['gini', 'entropy'],
}

# %%
gr_search = GridSearchCV(DecisionTreeClassifier(),
                      param_grid)

# %%
gr_search
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 18, 12, 10, 5],
#                          'min_samples_leaf': [1, 5, 10, 20]})

# %%
gr_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 18, 12, 10, 5],
#                          'min_samples_leaf': [1, 5, 10, 20]})

# %%
results = gr_search.cv_results_

# %%
results_df_init = pd.DataFrame(results)

# %%
results_df_init.shape
# Out:
# (40, 16)

# %%
params = pd.DataFrame(results['params'])

# %%
params
# Out:
#    criterion  max_depth  min_samples_leaf
# 0       gini        NaN                 1
# 1       gini        NaN                 5
# 2       gini        NaN                10
# 3       gini        NaN                20
# 4       gini       18.0                 1
# 5       gini       18.0                 5
# 6       gini       18.0                10
# 7       gini       18.0                20
# 8       gini       12.0                 1
# 9       gini       12.0                 5
# 10      gini       12.0                10
# 11      gini       12.0                20
# 12      gini       10.0                 1
# 13      gini       10.0                 5
# 14      gini       10.0                10
# 15      gini       10.0                20
# 16      gini        5.0                 1
# 17      gini        5.0                 5
# 18      gini        5.0                10
# 19      gini        5.0                20
# 20   entropy        NaN                 1
# 21   entropy        NaN                 5
# 22   entropy        NaN                10
# 23   entropy        NaN                20
# 24   entropy       18.0                 1
# 25   entropy       18.0                 5
# 26   entropy       18.0                10
# 27   entropy       18.0                20
# 28   entropy       12.0                 1
# 29   entropy       12.0                 5
# 30   entropy       12.0                10
# 31   entropy       12.0                20
# 32   entropy       10.0                 1
# 33   entropy       10.0                 5
# 34   entropy       10.0                10
# 35   entropy       10.0                20
# 36   entropy        5.0                 1
# 37   entropy        5.0                 5
# 38   entropy        5.0                10
# 39   entropy        5.0                20

# %%
results_df_init.sort_values(by='rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 37       0.004833      0.000040         0.000461        0.000007
# 2        0.010725      0.000403         0.000534        0.000003
# 38       0.004807      0.000034         0.000457        0.000003
# 17       0.004760      0.000040         0.000455        0.000007
# 16       0.004739      0.000056         0.000460        0.000005
# 36       0.004812      0.000030         0.000455        0.000005
# 29       0.010160      0.000134         0.000505        0.000006
# 20       0.016850      0.000423         0.000569        0.000003
# 28       0.010505      0.000105         0.000510        0.000009
# 30       0.009582      0.000154         0.000505        0.000002
# 18       0.004731      0.000048         0.000461        0.000007
# 24       0.014280      0.000210         0.000544        0.000008
# 10       0.009125      0.000121         0.000509        0.000007
# 6        0.010469      0.000302         0.000531        0.000004
# 34       0.008500      0.000123         0.000500        0.000005
# 19       0.004731      0.000038         0.000457        0.000003
# 33       0.008856      0.000108         0.000504        0.000007
# 14       0.008139      0.000104         0.000500        0.000011
# 22       0.011412      0.000334         0.000541        0.000006
# 32       0.009012      0.000116         0.000515        0.000046
# 39       0.004762      0.000031         0.000458        0.000003
# 9        0.009580      0.000123         0.000511        0.000008
# 8        0.009910      0.000101         0.000510        0.000003
# 0        0.021138      0.007692         0.000910        0.000512
# 26       0.011020      0.000234         0.000533        0.000012
# 12       0.008561      0.000141         0.000492        0.000003
# 1        0.012377      0.000486         0.000553        0.000001
# 21       0.013915      0.000608         0.000629        0.000094
# 25       0.012643      0.000257         0.000535        0.000002
# 13       0.008361      0.000089         0.000492        0.000005
# 4        0.012764      0.000248         0.000539        0.000006
# 5        0.011632      0.000302         0.000536        0.000002
# 15       0.007756      0.000103         0.000492        0.000005
# 3        0.009302      0.000580         0.000522        0.000006
# 11       0.008471      0.000229         0.000502        0.000005
# 35       0.007949      0.000145         0.000493        0.000004
# 31       0.008721      0.000243         0.000654        0.000309
# 7        0.009259      0.000502         0.000518        0.000003
# 27       0.009560      0.000478         0.000513        0.000003
# 23       0.009677      0.000558         0.000519        0.000003
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 37         entropy               5                      5
# 2             gini            None                     10
# 38         entropy               5                     10
# 17            gini               5                      5
# 16            gini               5                      1
# 36         entropy               5                      1
# 29         entropy              12                      5
# 20         entropy            None                      1
# 28         entropy              12                      1
# 30         entropy              12                     10
# 18            gini               5                     10
# 24         entropy              18                      1
# 10            gini              12                     10
# 6             gini              18                     10
# 34         entropy              10                     10
# 19            gini               5                     20
# 33         entropy              10                      5
# 14            gini              10                     10
# 22         entropy            None                     10
# 32         entropy              10                      1
# 39         entropy               5                     20
# 9             gini              12                      5
# 8             gini              12                      1
# 0             gini            None                      1
# 26         entropy              18                     10
# 12            gini              10                      1
# 1             gini            None                      5
# 21         entropy            None                      5
# 25         entropy              18                      5
# 13            gini              10                      5
# 4             gini              18                      1
# 5             gini              18                      5
# 15            gini              10                     20
# 3             gini            None                     20
# 11            gini              12                     20
# 35         entropy              10                     20
# 31         entropy              12                     20
# 7             gini              18                     20
# 27         entropy              18                     20
# 23         entropy            None                     20
#
#                                                params  split0_test_score  \
# 37  {'criterion': 'entropy', 'max_depth': 5, 'min_...           0.491892
# 2   {'criterion': 'gini', 'max_depth': None, 'min_...           0.501931
# 38  {'criterion': 'entropy', 'max_depth': 5, 'min_...           0.492664
# 17  {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.494981
# 16  {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.494208
# 36  {'criterion': 'entropy', 'max_depth': 5, 'min_...           0.491892
# 29  {'criterion': 'entropy', 'max_depth': 12, 'min...           0.496525
# 20  {'criterion': 'entropy', 'max_depth': None, 'm...           0.492664
# 28  {'criterion': 'entropy', 'max_depth': 12, 'min...           0.494981
# 30  {'criterion': 'entropy', 'max_depth': 12, 'min...           0.475676
# 18  {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.493436
# 24  {'criterion': 'entropy', 'max_depth': 18, 'min...           0.501931
# 10  {'criterion': 'gini', 'max_depth': 12, 'min_sa...           0.487259
# 6   {'criterion': 'gini', 'max_depth': 18, 'min_sa...           0.502703
# 34  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.482625
# 19  {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.494208
# 33  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.493436
# 14  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.486486
# 22  {'criterion': 'entropy', 'max_depth': None, 'm...           0.495753
# 32  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.494981
# 39  {'criterion': 'entropy', 'max_depth': 5, 'min_...           0.492664
# 9   {'criterion': 'gini', 'max_depth': 12, 'min_sa...           0.492664
# 8   {'criterion': 'gini', 'max_depth': 12, 'min_sa...           0.501158
# 0   {'criterion': 'gini', 'max_depth': None, 'min_...           0.498069
# 26  {'criterion': 'entropy', 'max_depth': 18, 'min...           0.482625
# 12  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.505019
# 1   {'criterion': 'gini', 'max_depth': None, 'min_...           0.493436
# 21  {'criterion': 'entropy', 'max_depth': None, 'm...           0.486486
# 25  {'criterion': 'entropy', 'max_depth': 18, 'min...           0.477992
# 13  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.489575
# 4   {'criterion': 'gini', 'max_depth': 18, 'min_sa...           0.483398
# 5   {'criterion': 'gini', 'max_depth': 18, 'min_sa...           0.482625
# 15  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.481081
# 3   {'criterion': 'gini', 'max_depth': None, 'min_...           0.482625
# 11  {'criterion': 'gini', 'max_depth': 12, 'min_sa...           0