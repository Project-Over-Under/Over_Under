# %%
import pandas as pd
import numpy as np
import re

# %%
pd.read_csv('nflprep.csv')
# Out:
#                date day_of_week start_time  week_num             home_team  \
# 0      Feb 12, 2023      Sunday    6:30 PM  Playoffs   Philadelphia Eagles
# 1      Jan 29, 2023      Sunday    3:00 PM  Playoffs   Philadelphia Eagles
# 2      Jan 29, 2023      Sunday    6:30 PM  Playoffs    Kansas City Chiefs
# 3      Jan 22, 2023      Sunday    3:00 PM  Playoffs         Buffalo Bills
# 4      Jan 22, 2023      Sunday    6:30 PM  Playoffs   San Francisco 49ers
# ...             ...         ...        ...       ...                   ...
# 11051   Sep 2, 1979      Sunday    4:00 PM    Week 1    Kansas City Chiefs
# 11052   Sep 2, 1979      Sunday    4:00 PM    Week 1         New York Jets
# 11053   Sep 2, 1979      Sunday    4:00 PM    Week 1      Los Angeles Rams
# 11054   Sep 2, 1979      Sunday    4:00 PM    Week 1      Seattle Seahawks
# 11055   Sep 1, 1979    Saturday    8:00 PM    Week 1  Tampa Bay Buccaneers
#
# ...

# %%
df = pd.read_csv('nflprep.csv')

# %%
df.head()
# Out:
#            date day_of_week start_time  week_num            home_team  \
# 0  Feb 12, 2023      Sunday    6:30 PM  Playoffs  Philadelphia Eagles
# 1  Jan 29, 2023      Sunday    3:00 PM  Playoffs  Philadelphia Eagles
# 2  Jan 29, 2023      Sunday    6:30 PM  Playoffs   Kansas City Chiefs
# 3  Jan 22, 2023      Sunday    3:00 PM  Playoffs        Buffalo Bills
# 4  Jan 22, 2023      Sunday    6:30 PM  Playoffs  San Francisco 49ers
#
#    home_score home_wins            away_team  away_score away_wins  \
# 0          35      16-4   Kansas City Chiefs          38      17-3
# 1          31      16-3  San Francisco 49ers           7      15-5
# 2          23      16-3   Cincinnati Bengals          20      14-5
# 3          10      14-4   Cincinnati Bengals          27      14-4
# 4          19      15-4       Dallas Cowboys          12      13-6
#
#                            stadium surface                     roof  temp  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11056 entries, 0 to 11055
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         11056 non-null  object
#  1   day_of_week  11056 non-null  object
#  2   start_time   11056 non-null  object
#  3   week_num     11056 non-null  object
#  4   home_team    11056 non-null  object
#  5   home_score   11056 non-null  int64
#  6   home_wins    11056 non-null  object
#  7   away_team    11056 non-null  object
#  8   away_score   11056 non-null  int64
#  9   away_wins    11056 non-null  object
#  10  stadium      11056 non-null  object
#  11  surface      11056 non-null  object
#  12  roof         11056 non-null  object
#  13  temp         10415 non-null  float64
#  14  humidity     11056 non-null  int64
#  15  wind         11056 non-null  int64
#  16  spread       11056 non-null  float64
#  17  ou           11056 non-null  object
# ...

# %%
df['date'] = pd.to_datetime(df.date)

# %%
time_re = r'^[0-9]{1,2}'

# %%
re.findall(time_re,df['start_time'][1])
# Out:
# ['3']

# %%
df['start_time'] = df['start_time'].apply(lambda x: re.findall(time_re,x)[0])

# %%
df.head()
# Out:
#         date day_of_week start_time  week_num            home_team  \
# 0 2023-02-12      Sunday          6  Playoffs  Philadelphia Eagles
# 1 2023-01-29      Sunday          3  Playoffs  Philadelphia Eagles
# 2 2023-01-29      Sunday          6  Playoffs   Kansas City Chiefs
# 3 2023-01-22      Sunday          3  Playoffs        Buffalo Bills
# 4 2023-01-22      Sunday          6  Playoffs  San Francisco 49ers
#
#    home_score home_wins            away_team  away_score away_wins  \
# 0          35      16-4   Kansas City Chiefs          38      17-3
# 1          31      16-3  San Francisco 49ers           7      15-5
# 2          23      16-3   Cincinnati Bengals          20      14-5
# 3          10      14-4   Cincinnati Bengals          27      14-4
# 4          19      15-4       Dallas Cowboys          12      13-6
#
#                            stadium surface                     roof  temp  \
# 0               State Farm Stadium   grass  retractable roof (open)  72.0
# ...

# %%
normal_day = ['Sunday']
normal_time = ['12','1','2','3','4','5','6']
results = [0]

# %%
mapping = {
    'Sunday': 0,
    'Maonday': 'BOB',
    'Cathy': 'CATHY'
}

# %%
# def abnormal(a,b):
#     normal_day = ['Sunday']
#     normal_time = ['12','1','2','3','4','5','6']
#     if (a in normal_day) and (b in normal_time):
#         return 0
#     else:
#         return 1

# %%
#df['upper_name'] = df['name'].replace(mapping)

# %%
#df['normal_day'] df['day_of_week'].replace(mapping)

# %%
df.head()
# Out:
#         date day_of_week start_time  week_num            home_team  \
# 0 2023-02-12      Sunday          6  Playoffs  Philadelphia Eagles
# 1 2023-01-29      Sunday          3  Playoffs  Philadelphia Eagles
# 2 2023-01-29      Sunday          6  Playoffs   Kansas City Chiefs
# 3 2023-01-22      Sunday          3  Playoffs        Buffalo Bills
# 4 2023-01-22      Sunday          6  Playoffs  San Francisco 49ers
#
#    home_score home_wins            away_team  away_score away_wins  \
# 0          35      16-4   Kansas City Chiefs          38      17-3
# 1          31      16-3  San Francisco 49ers           7      15-5
# 2          23      16-3   Cincinnati Bengals          20      14-5
# 3          10      14-4   Cincinnati Bengals          27      14-4
# 4          19      15-4       Dallas Cowboys          12      13-6
#
#                            stadium surface                     roof  temp  \
# 0               State Farm Stadium   grass  retractable roof (open)  72.0
# ...

# %% [markdown]
# ## OUTDOORS and TURF BOOLS

# %%
df['is_turf'] = np.where(df['surface'] != 'grass', 1, 0)

# %%
df.head()
# Out:
#         date day_of_week start_time  week_num            home_team  \
# 0 2023-02-12      Sunday          6  Playoffs  Philadelphia Eagles
# 1 2023-01-29      Sunday          3  Playoffs  Philadelphia Eagles
# 2 2023-01-29      Sunday          6  Playoffs   Kansas City Chiefs
# 3 2023-01-22      Sunday          3  Playoffs        Buffalo Bills
# 4 2023-01-22      Sunday          6  Playoffs  San Francisco 49ers
#
#    home_score home_wins            away_team  away_score away_wins  ...  \
# 0          35      16-4   Kansas City Chiefs          38      17-3  ...
# 1          31      16-3  San Francisco 49ers           7      15-5  ...
# 2          23      16-3   Cincinnati Bengals          20      14-5  ...
# 3          10      14-4   Cincinnati Bengals          27      14-4  ...
# 4          19      15-4       Dallas Cowboys          12      13-6  ...
#
#   surface                     roof  temp  humidity  wind  spread    ou  \
# ...

# %%
df['is_outdoor'] = np.where(df['roof'] == 'outdoors', 1, 0)

# %%
df.head()
# Out:
#         date day_of_week start_time  week_num            home_team  \
# 0 2023-02-12      Sunday          6  Playoffs  Philadelphia Eagles
# 1 2023-01-29      Sunday          3  Playoffs  Philadelphia Eagles
# 2 2023-01-29      Sunday          6  Playoffs   Kansas City Chiefs
# 3 2023-01-22      Sunday          3  Playoffs        Buffalo Bills
# 4 2023-01-22      Sunday          6  Playoffs  San Francisco 49ers
#
#    home_score home_wins            away_team  away_score away_wins  ...  \
# 0          35      16-4   Kansas City Chiefs          38      17-3  ...
# 1          31      16-3  San Francisco 49ers           7      15-5  ...
# 2          23      16-3   Cincinnati Bengals          20      14-5  ...
# 3          10      14-4   Cincinnati Bengals          27      14-4  ...
# 4          19      15-4       Dallas Cowboys          12      13-6  ...
#
#                       roof  temp humidity  wind  spread    ou  is_under  \
# ...

# %%
wins_re = r'^[0-9]{1,2}'

# %%
re.findall(wins_re,df.home_wins[0])
# Out:
# ['16']

# %%
def wins(row):
    wins_re = r'^[0-9]{1,2}'
    return re.findall(wins_re,row['home_wins'])

# %%
wins(df.home_wins[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 wins(df.home_wins[0])
#
# Input In [42], in wins(row)
#       1 def wins(row):
#       2     wins_re = r'^[0-9]{1,2}'
# ----> 3     return re.findall(wins_re,row['home_wins'])
#
# TypeError: string indices must be integers

# %%
df['home_wins_a'] = df['home_wins'].apply(re.findall(wins_re,df['home_wins']),axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 df['home_wins_a'] = df['home_wins'].apply(re.findall(wins_re,df['home_wins'][x]),axis=1)
#
# NameError: name 'x' is not defined
